# %%
#importing standard libraries.  More esoteric libraries
#will be imported down below as needed

import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

import re

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.style.use("ggplot")

from nltk.corpus import stopwords

# %%
#import data set as dataframe and use smaller subset
#for simple modeling purposes
df=pd.read_csv("data/rotten_tomatoes_reviews.csv")
df_quick = df[:20000]
#df_quick

# %%
#using regexp notation to get rid of numbers in reviews
df_new = df_quick.copy()
df_new["Review"] = df_new["Review"].str.replace(r'([^a-zA-Z\s]+?)'," ")
df_new.Review[0]
# r"\d+"
# Out:
# ' Manakamana doesn t answer any questions  yet makes its point  Nepal  like the rest of our planet  is a picturesque but far from peaceable kingdom '

# %%
#create a model to make a word counts matrix from the docs
#This model will lowercase words, stip accents, take out english stop words, and 
# take out obscure words, and possibly words that appear to often

count_vect = CountVectorizer(lowercase=True, tokenizer=None, strip_accents= "ascii", stop_words='english',
                             analyzer='word', max_df=1.0, min_df=2,ngram_range=(1,1),
                             max_features=3000)
X_train_counts = count_vect.fit_transform(df_quick.Review.values)

# %%
# These are the words in our vocabulary to serve as 
# feature names
feature_names = count_vect.get_feature_names()
feature_names
# Out:
# ['10',
#  '100',
#  '11',
#  '12',
#  '13',
#  '15',
#  '20',
#  '2010',
#  '2015',
#  '21st',
#  '30',
#  '3d',
#  '40',
#  '45',
#  '50',
#  '70s',
#  '80s',
#  '90',
#  '90s',
#  'abandon',
#  'ability',
#  'able',
#  'absent',
#  'absolute',
#  'absolutely',
#  'absorbing',
#  'absurd',
#  'abuse',
#  'accessible',
#  'accomplished',
#  'account',
#  'accurate',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achieves',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'activity',
#  'actor',
#  'actors',
#  'actress',
#  'acts',
#  'actual',
#  'actually',
#  'ad',
#  'adam',
#  'adaptation',
#  'adaptations',
#  'add',
#  'addition',
#  'adds',
#  'adequate',
#  'admirable',
#  'admire',
#  'admit',
#  'adolescence',
#  'adolescent',
#  'adult',
#  'adults',
#  'adventure',
#  'adventures',
#  'aesthetic',
#  'affair',
#  'affecting',
#  'affection',
#  'affleck',
#  'afraid',
#  'african',
#  'age',
#  'agenda',
#  'agent',
#  'ages',
#  'aggressively',
#  'ago',
#  'ahead',
#  'aimed',
#  'aims',
#  'ain',
#  'air',
#  'al',
#  'alas',
#  'albeit',
#  'alice',
#  'alien',
#  'aliens',
#  'alike',
#  'alive',
#  'allegory',
#  'allen',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'altogether',
#  'amazing',
#  'ambiguity',
#  'ambition',
#  'ambitions',
#  'ambitious',
#  'america',
#  'american',
#  'amiable',
#  'amid',
#  'amounts',
#  'amusement',
#  'amusing',
#  'amy',
#  'anderson',
#  'andrew',
#  'angels',
#  'anger',
#  'angry',
#  'angst',
#  'animal',
#  'animals',
#  'animated',
#  'animation',
#  'anna',
#  'annoying',
#  'answer',
#  'answers',
#  'anthony',
#  'anti',
#  'antics',
#  'anybody',
#  'apart',
#  'apatow',
#  'apocalypse',
#  'apocalyptic',
#  'apparently',
#  'appeal',
#  'appealing',
#  'appear',
#  'appears',
#  'appreciate',
#  'appreciated',
#  'appreciation',
#  'approach',
#  'approaches',
#  'appropriate',
#  'arc',
#  'aren',
#  'argument',
#  'arresting',
#  'art',
#  'arthur',
#  'artificial',
#  'artist',
#  'artistic',
#  'artistry',
#  'arts',
#  'aside',
#  'ask',
#  'asking',
#  'asks',
#  'aspect',
#  'aspects',
#  'aspirations',
#  'ass',
#  'assembled',
#  'assured',
#  'astonishing',
#  'atmosphere',
#  'atmospheric',
#  'attached',
#  'attack',
#  'attempt',
#  'attempts',
#  'attention',
#  'attitude',
#  'attraction',
#  'attractive',
#  'audacious',
#  'audience',
#  'audiences',
#  'authentic',
#  'authenticity',
#  'available',
#  'average',
#  'avoid',
#  'avoids',
#  'aware',
#  'awareness',
#  'away',
#  'awe',
#  'awesome',
#  'awful',
#  'awkward',
#  'baby',
#  'background',
#  'bad',
#  'badly',
#  'bag',
#  'baked',
#  'balance',
#  'balancing',
#  'ball',
#  'balls',
#  'banal',
#  'band',
#  'bang',
#  'bar',
#  'barely',
#  'based',
#  'basic',
#  'basically',
#  'basis',
#  'batman',
#  'battle',
#  'bay',
#  'bear',
#  'beast',
#  'beat',
#  'beats',
#  'beautiful',
#  'beautifully',
#  'beauty',
#  'begin',
#  'beginning',
#  'begins',
#  'behavior',
#  'behold',
#  'beings',
#  'believable',
#  'believe',
#  'bell',
#  'belongs',
#  'beloved',
#  'ben',
#  'beneath',
#  'benefits',
#  'besson',
#  'best',
#  'betrayal',
#  'better',
#  'big',
#  'bigger',
#  'biggest',
#  'biography',
#  'biopic',
#  'bird',
#  'bit',
#  'bite',
#  'bits',
#  'bitter',
#  'bittersweet',
#  'bizarre',
#  'black',
#  'blade',
#  'blame',
#  'bland',
#  'blast',
#  'bleak',
#  'blend',
#  'blends',
#  'bloated',
#  'blockbuster',
#  'blonde',
#  'blood',
#  'bloody',
#  'blow',
#  'blown',
#  'blows',
#  'blue',
#  'blunt',
#  'board',
#  'boasts',
#  'body',
#  'bogged',
#  'bold',
#  'bond',
#  'bone',
#  'bones',
#  'book',
#  'books',
#  'bore',
#  'bored',
#  'boring',
#  'born',
#  'bottle',
#  'bound',
#  'bourne',
#  'box',
#  'boy',
#  'boyle',
#  'boys',
#  'brad',
#  'brain',
#  'brand',
#  'brave',
#  'break',
#  'breaking',
#  'breath',
#  'breathless',
#  'breathtaking',
#  'breezy',
#  'brief',
#  'bright',
#  'brilliance',
#  'brilliant',
#  'brilliantly',
#  'bring',
#  'bringing',
#  'brings',
#  'brisk',
#  'british',
#  'broad',
#  'broken',
#  'brooks',
#  'brother',
#  'brothers',
#  'brought',
#  'brown',
#  'bruce',
#  'brutal',
#  'brutality',
#  'brutally',
#  'buddy',
#  'budget',
#  'build',
#  'building',
#  'builds',
#  'built',
#  'bullock',
#  'bunch',
#  'buried',
#  'burn',
#  'burning',
#  'burton',
#  'business',
#  'busy',
#  'buy',
#  'cable',
#  'cage',
#  'cake',
#  'called',
#  'calling',
#  'came',
#  'camera',
#  'camerawork',
#  'cameron',
#  'camp',
#  'campy',
#  'candy',
#  'canon',
#  'capable',
#  'caper',
#  'captain',
#  'captivating',
#  'capture',
#  'captures',
#  'capturing',
#  'car',
#  'card',
#  'care',
#  'career',
#  'careful',
#  'carefully',
#  'cares',
#  'carnage',
#  'carpenter',
#  'carrey',
#  'carries',
#  'carry',
#  'cars',
#  'cartoon',
#  'case',
#  'cash',
#  'cast',
#  'casting',
#  'casual',
#  'cat',
#  'catch',
#  'catching',
#  'caught',
#  'cause',
#  'cautionary',
#  'celebration',
#  'center',
#  'central',
#  'century',
#  'certain',
#  'certainly',
#  'cgi',
#  'challenge',
#  'challenging',
#  'chance',
#  'chances',
#  'change',
#  'changes',
#  'changing',
#  'channel',
#  'chaos',
#  'chaotic',
#  'chapter',
#  'character',
#  'characterization',
#  'characters',
#  'charged',
#  'charisma',
#  'charismatic',
#  'charlie',
#  'charm',
#  'charming',
#  'charmless',
#  'charms',
#  'chase',
#  'chases',
#  'cheap',
#  'check',
#  'cheer',
#  'cheesy',
#  'chemistry',
#  'chew',
#  'chick',
#  'child',
#  'childhood',
#  'children',
#  'chilling',
#  'choice',
#  'choices',
#  'choose',
#  'chore',
#  'chosen',
#  'chris',
#  'christian',
#  'christmas',
#  'christopher',
#  'cinema',
#  'cinematic',
#  'cinematographer',
#  'cinematography',
#  'circle',
#  'circumstances',
#  'city',
#  'civil',
#  'claim',
#  'clash',
#  'class',
#  'classic',
#  'classics',
#  'claustrophobic',
#  'clean',
#  'clear',
#  'clearly',
#  'clever',
#  'cleverly',
#  'cliche',
#  'cliched',
#  'cliches',
#  'climactic',
#  'climax',
#  'clint',
#  'clooney',
#  'close',
#  'closely',
#  'closer',
#  'closing',
#  'club',
#  'clumsy',
#  'clunky',
#  'code',
#  'coen',
#  'cohen',
#  'coherent',
#  'cohesive',
#  'cold',
#  'collapses',
#  'collection',
#  'collective',
#  'college',
#  'color',
#  'colorful',
#  'colors',
#  'com',
#  'combination',
#  'combined',
#  'combines',
#  'come',
#  'comedic',
#  'comedies',
#  'comedy',
#  'comes',
#  'comfort',
#  'comfortable',
#  'comic',
#  'comics',
#  'coming',
#  'commentary',
#  'commercial',
#  'commitment',
#  'committed',
#  'common',
#  'community',
#  'company',
#  'compared',
#  'comparison',
#  'compassion',
#  'compelling',
#  'competent',
#  'complete',
#  'completely',
#  'complex',
#  'complexity',
#  'complicated',
#  'computer',
#  'conceit',
#  'conceived',
#  'concept',
#  'concerned',
#  'concert',
#  'conclusion',
#  'condescending',
#  'confidence',
#  'confident',
#  'conflict',
#  'confused',
#  'confusing',
#  'connect',
#  'connection',
#  'connections',
#  'conscience',
#  'consciously',
#  'consequences',
#  'consider',
#  'considerable',
#  'considered',
#  'considering',
#  'consistent',
#  'consistently',
#  'conspiracy',
#  'constant',
#  'constantly',
#  'constructed',
#  'contains',
#  'contemporary',
#  'content',
#  'context',
#  'continue',
#  'continues',
#  'contrivances',
#  'contrived',
#  'control',
#  'conventional',
#  'conventions',
#  'conversation',
#  'convey',
#  'conveys',
#  'conviction',
#  'convince',
#  'convincing',
#  'convoluted',
#  'coogan',
#  'cool',
#  'cooper',
#  'cop',
#  'coppola',
#  'copy',
#  'core',
#  'corner',
#  'corny',
#  'corporate',
#  'cost',
#  'costner',
#  'costume',
#  'costumes',
#  'couldn',
#  'count',
#  'country',
#  'couple',
#  'courage',
#  'course',
#  'cover',
#  'craft',
#  'crafted',
#  'craig',
#  'crash',
#  'crass',
#  'crazy',
#  'create',
#  'created',
#  'creates',
#  'creating',
#  'creation',
#  'creative',
#  'creativity',
#  'creature',
#  'creatures',
#  'credibility',
#  'credit',
#  'credits',
#  'creed',
#  'creepy',
#  'crew',
#  'crime',
#  'criminal',
#  'cringe',
#  'crisis',
#  'critic',
#  'critical',
#  'cronenberg',
#  'cross',
#  'crowd',
#  'crowe',
#  'crucial',
#  'crude',
#  'cruel',
#  'cruelty',
#  'cruise',
#  'cult',
#  'cultural',
#  'culture',
#  'curious',
#  'curiously',
#  'current',
#  'curtis',
#  'cut',
#  'cute',
#  'cuts',
#  'cutting',
#  'cynical',
#  'cynicism',
#  'damn',
#  'dance',
#  'dancing',
#  'dangerous',
#  'daniel',
#  'dare',
#  'daring',
#  'dark',
#  'darker',
#  'darkly',
#  'darkness',
#  'date',
#  'dated',
#  'daughter',
#  'david',
#  'dawn',
#  'day',
#  'days',
#  'dazzling',
#  'dead',
#  'deadpool',
#  'deal',
#  'dealing',
#  'death',
#  'debut',
#  'decade',
#  'decades',
#  'decent',
#  'decide',
#  'decidedly',
#  'decision',
#  'decisions',
#  'deep',
#  'deeper',
#  'deeply',
#  'defined',
#  'definitely',
#  'deft',
#  'deftly',
#  'degree',
#  'del',
#  'deliberately',
#  'delicate',
#  'delicious',
#  'delight',
#  'delightful',
#  'delightfully',
#  'delights',
#  'deliver',
#  'delivered',
#  'delivering',
#  'delivers',
#  'demands',
#  'demons',
#  'demonstrates',
#  'denzel',
#  'department',
#  'depiction',
#  'depicts',
#  'depp',
#  'depressing',
#  'depth',
#  'depths',
#  'derivative',
#  'desert',
#  'deserve',
#  'deserves',
#  'design',
#  'designed',
#  'desire',
#  'desperate',
#  'desperately',
#  'desperation',
#  'despite',
#  'destination',
#  'destined',
#  'detailed',
#  'details',
#  'determined',
#  'devastating',
#  'developed',
#  'development',
#  'device',
#  'devil',
#  'devoid',
#  'dialogue',
#  'did',
#  'didn',
#  'die',
#  'difference',
#  'different',
#  'difficult',
#  'digital',
#  'dimension',
#  'dimensional',
#  'dinner',
#  'direct',
#  'directed',
#  'directing',
#  'direction',
#  'directly',
#  'director',
#  'directorial',
#  'directors',
#  'directs',
#  'dirty',
#  'disappointed',
#  'disappointing',
#  'disappointingly',
#  'disappointment',
#  'disaster',
#  'disbelief',
#  'discover',
#  'discovery',
#  'disjointed',
#  'disney',
#  'disparate',
#  'display',
#  'displays',
#  'disposable',
#  'distance',
#  'distinctive',
#  'disturbing',
#  'diversion',
#  'diverting',
#  'doc',
#  'document',
#  'documentaries',
#  'documentary',
#  'does',
#  'doesn',
#  'dog',
#  'dogs',
#  'doing',
#  'dollar',
#  'domestic',
#  'don',
#  'door',
#  'dopey',
#  'double',
#  'doubt',
#  'douglas',
#  'downright',
#  'dr',
#  'drag',
#  'dragon',
#  'drags',
#  'drama',
#  'dramas',
#  'dramatic',
#  'dramatically',
#  'dramedy',
#  'draw',
#  'drawn',
#  'draws',
#  'dread',
#  'dream',
#  'dreams',
#  'dreary',
#  'dressed',
#  'drive',
#  'driven',
#  'driver',
#  'drives',
#  'driving',
#  'drop',
#  'drug',
#  'drugs',
#  'dry',
#  'dude',
#  'dull',
#  'dumb',
#  'dvd',
#  'dynamic',
#  'dynamics',
#  'eager',
#  'earlier',
#  'early',
#  'earn',
#  'earnest',
#  'earns',
#  'earth',
#  'easily',
#  'eastwood',
#  'easy',
#  'eat',
#  'eccentric',
#  'economic',
#  'ed',
#  'edge',
#  'edges',
#  'edgy',
#  'edited',
#  'editing',
#  'eerie',
#  'effect',
#  'effective',
#  'effectively',
#  'effects',
#  'efficient',
#  'effort',
#  'efforts',
#  'el',
#  'elaborate',
#  'elegant',
#  'element',
#  'elements',
#  'elevate',
#  'elizabeth',
#  'em',
#  'embarrassing',
#  'embrace',
#  'emerges',
#  'emotion',
#  'emotional',
#  'emotionally',
#  'emotions',
#  'empathy',
#  'emphasis',
#  'empire',
#  'en',
#  'end',
#  'endearing',
#  'endeavor',
#  'ended',
#  'ending',
#  'endless',
#  'endlessly',
#  'ends',
#  'endure',
#  'enduring',
#  'energetic',
#  'energy',
#  'engage',
#  'engaged',
#  'engaging',
#  'english',
#  'engrossing',
#  'enjoy',
#  'enjoyable',
#  'enjoyed',
#  'enormous',
#  'ensemble',
#  'entertain',
#  'entertaining',
#  'entertainment',
#  'enthusiasm',
#  'entire',
#  'entirely',
#  'entries',
#  'entry',
#  'epic',
#  'episode',
#  'equal',
#  'equally',
#  'equivalent',
#  'era',
#  'escape',
#  'escapism',
#  'escapist',
#  'especially',
#  'esque',
#  'essence',
#  'essential',
#  'essentially',
#  'established',
#  'european',
#  'event',
#  'events',
#  'eventually',
#  'everybody',
#  'everyday',
#  'evidence',
#  'evil',
#  'exactly',
#  'examination',
#  'example',
#  'excellent',
#  'exceptional',
#  'excess',
#  'excessive',
#  'excitement',
#  'exciting',
#  'excuse',
#  'executed',
#  'execution',
#  'exercise',
#  'exhausting',
#  'exhilarating',
#  'exist',
#  'existence',
#  'exists',
#  'exotic',
#  'expect',
#  'expectations',
#  'expected',
#  'expecting',
#  'expensive',
#  'experience',
#  'experienced',
#  'experiences',
#  'experiment',
#  'expertly',
#  'explain',
#  'exploit',
#  'exploitation',
#  'exploration',
#  'explore',
#  'explores',
#  'exploring',
#  'explosions',
#  'explosive',
#  'expose',
#  'exposition',
#  'express',
#  'exquisite',
#  'extended',
#  'extra',
#  'extraordinary',
#  'extreme',
#  'extremely',
#  'exuberant',
#  'eye',
#  'eyed',
#  'eyes',
#  'fable',
#  'fabulous',
#  'face',
#  'faced',
#  'faces',
#  'fact',
#  'factor',
#  'factory',
#  'fail',
#  'failed',
#  'fails',
#  'failure',
#  'fair',
#  'fairly',
#  'fairy',
#  'faith',
#  'faithful',
#  'fake',
#  'fall',
#  'fallen',
#  'falling',
#  'falls',
#  'false',
#  'fame',
#  'familiar',
#  'families',
#  'family',
#  'famous',
#  'fan',
#  'fans',
#  'fantastic',
#  'fantasy',
#  'far',
#  'farce',
#  'fare',
#  'fascinating',
#  'fashion',
#  'fashioned',
#  'fast',
#  'fat',
#  'fatal',
#  'fate',
#  'father',
#  'favor',
#  'favorite',
#  'fear',
#  'fears',
#  'feast',
#  'feat',
#  'feature',
#  ...]

# %%
#create bag of words dictionary to get lookup table
# for words in matrix
for key in sorted(count_vect.vocabulary_.keys()):
    print("{0:<20s} {1}".format(key, count_vect.vocabulary_[key]))
# Out:
# 10                   0
# 100                  1
# 11                   2
# 12                   3
# 13                   4
# 15                   5
# 20                   6
# 2010                 7
# 2015                 8
# 21st                 9
# 30                   10
# 3d                   11
# 40                   12
# 45                   13
# 50                   14
# 70s                  15
# 80s                  16
# 90                   17
# 90s                  18
# abandon              19
# ability              20
# able                 21
# absent               22
# absolute             23
# absolutely           24
# absorbing            25
# absurd               26
# abuse                27
# accessible           28
# accomplished         29
# account              30
# accurate             31
# achieve              32
# achieved             33
# achievement          34
# achieves             35
# act                  36
# acted                37
# acting               38
# action               39
# activity             40
# actor                41
# actors               42
# actress              43
# acts                 44
# actual               45
# actually             46
# ad                   47
# adam                 48
# adaptation           49
# adaptations          50
# add                  51
# addition             52
# adds                 53
# adequate             54
# admirable            55
# admire               56
# admit                57
# adolescence          58
# adolescent           59
# adult                60
# adults               61
# adventure            62
# adventures           63
# aesthetic            64
# affair               65
# affecting            66
# affection            67
# affleck              68
# afraid               69
# african              70
# age                  71
# agenda               72
# agent                73
# ages                 74
# aggressively         75
# ago                  76
# ahead                77
# aimed                78
# aims                 79
# ain                  80
# air                  81
# al                   82
# alas                 83
# albeit               84
# alice                85
# alien                86
# aliens               87
# alike                88
# alive                89
# allegory             90
# allen                91
# allow                92
# allowed              93
# allowing             94
# allows               95
# altogether           96
# amazing              97
# ambiguity            98
# ambition             99
# ambitions            100
# ambitious            101
# america              102
# american             103
# amiable              104
# amid                 105
# amounts              106
# amusement            107
# amusing              108
# amy                  109
# anderson             110
# andrew               111
# angels               112
# anger                113
# angry                114
# angst                115
# animal               116
# animals              117
# animated             118
# animation            119
# anna                 120
# annoying             121
# answer               122
# answers              123
# anthony              124
# anti                 125
# antics               126
# anybody              127
# apart                128
# apatow               129
# apocalypse           130
# apocalyptic          131
# apparently           132
# appeal               133
# appealing            134
# appear               135
# appears              136
# appreciate           137
# appreciated          138
# appreciation         139
# approach             140
# approaches           141
# appropriate          142
# arc                  143
# aren                 144
# argument             145
# arresting            146
# art                  147
# arthur               148
# artificial           149
# artist               150
# artistic             151
# artistry             152
# arts                 153
# aside                154
# ask                  155
# wouldn               2978
# wrapped              2979
# wrenching            2980
# wright               2981
# write                2982
# writer               2983
# writers              2984
# writing              2985
# written              2986
# wrong                2987
# wrote                2988
# yarn                 2989
# year                 2990
# years                2991
# yes                  2992
# york                 2993
# young                2994
# younger              2995
# youth                2996
# zero                 2997
# zombie               2998
# zone                 2999

# %%
count_vect.vocabulary_.keys()
# Out:
# dict_keys(['doesn', 'answer', 'questions', 'makes', 'point', 'like', 'rest', 'planet', 'far', 'kingdom', 'offensive', 'good', 'clean', 'fun', 'difficult', 'imagine', 'material', 'wrong', 'lost', 'despite', 'gusto', 'star', 'brings', 'role', 'hard', 'ride', 'discovery', 'idea', 'core', 'film', 'buried', 'jokes', 'dog', 'bad', 'ridiculous', 'plot', 'goes', 'channel', 'intermittently', 'curious', 'entry', 'time', 'travel', 'satire', 'dark', 'hell', 'absurd', 'surely', 'close', 'reality', 'era', 'deserves', 'better', 'movie', 'actor', 'embrace', 'season', 'slight', 'bell', 'debut', 'feature', 'subject', 'humor', 'intelligence', 'issue', 'performance', 'shamelessly', 'music', 'score', 'director', 'halloween', 'achieves', 'considerable', 'power', 'entirely', 'visual', 'means', 'people', 'action', 'thrills', 'son', 'filmmaking', 'turn', 'doing', 'cinema', 'does', 'best', 'hands', 'great', 'filmmakers', 'showing', 'telling', 'isn', 'thrilling', 'fox', 'act', 'funny', 'lovely', 'watch', 'need', 'chew', 'stronger', 'predecessor', 'deeply', 'felt', 'love', 'story', 'conventions', 'feel', 'baby', 'just', 'head', 'long', 'unfocused', 'immersive', 'pulled', 'knight', 'direction', 'studio', 'technical', 'easy', 'enjoy', 'sort', 'thing', 'leaves', 'think', 'brooks', 'missed', 'make', 'worthwhile', 'extraordinary', 'blast', 'past', 'men', 'class', 'decade', 'superhero', 'movies', 'lightweight', 'interesting', 'villain', 'black', 'rage', 'drawn', 'period', 'strange', 'crafted', 'accurate', 'wears', 'deep', 'dramatic', 'elements', 'emotional', 'effect', 'fall', 'slasher', 'game', 'decent', 'fourth', 'final', 'american', 'pie', 'reason', 'actors', 'haven', 'worked', 'sequels', 'simply', 'aren', 'special', 'free', 'staged', 'paced', 'uneven', 'question', 'things', 'happening', 'dull', 'minutes', 'worth', 'comedy', 'coen', 'brothers', 'worst', 'marvelous', 'mystery', 'critic', 'directed', 'john', 'follows', 'numbers', 'plodding', 'unimaginative', 'set', 'piece', 'visceral', 'tears', 'manages', 'avoid', 'high', 'minded', 'seriousness', 'trash', 'exercise', 'want', 'body', 'count', 'step', 'right', 'hidden', 'agenda', 'eventually', 'credibility', 'ability', 'allows', 'flight', 'deliver', 'romantic', 'new', 'offer', 'rise', 'wealth', 'race', 'relies', 'stereotypes', 'having', 'heart', 'place', 'excuse', 'living', 'life', 'edge', 'disaster', 'boyle', 'breathtaking', 'works', 'fine', 'stand', 'entertainment', 'series', 'hangover', 'ii', 'justify', 'effort', 'spent', 'add', 'nearly', 'original', 'amy', 'favorite', 'drug', 'turned', 'school', 'quite', 'big', 'screen', 'version', 'cult', 'tv', 'faces', 'camera', 'shadows', 'moving', 'large', 'looking', 'building', 'images', 'amusement', 'park', 'magical', 'quiet', 'documentary', 'gorgeous', 'teenagers', 'goofy', 'hope', 'beautifully', 'shot', 'aggressively', 'turns', 'sumptuous', 'hide', 'eyes', 'disturbing', 'concept', 'execution', 'gyllenhaal', 'old', 'song', 'ain', 'harder', 'hold', 'times', 'trying', 'say', 'says', 'fight', 'sequence', 'blows', 'delivered', 'little', 'lasting', 'impact', 'work', 'raising', 'complex', 'identity', 'playing', 'possibly', 'deliberately', 'ambiguity', 'revolutionary', 'message', 'got', 'coming', 'girl', 'sharply', 'written', 'entertaining', 'disappointing', 'desperate', 'nudity', 'appreciate', 'younger', 'truly', 'wanted', 'way', 've', 'achieved', 'expect', 'horror', 'thriller', 'based', 'true', 'actual', 'events', 'sell', 'merely', 'viewer', 'delight', 'hilarity', 'generated', 'mr', 'cable', 'guy', 'breaking', 'wind', 'various', 'said', 'sweet', 'charming', 'loss', 'beloved', 'leading', 'man', 'picture', 'extra', 'unexpected', 'pathos', 'adequate', 'animated', 'children', 'played', 'comic', 'book', 'superheroes', 'short', 'fresh', 'ideas', 'thanks', 'strong', 'performances', 'script', 'provides', 'depth', 'characters', 'collection', 'thought', 'oscar', 'winning', 'drama', 'crash', 'heavy', 'handed', 'wait', 'view', 'trite', 'supposed', 'wit', 'leave', 'wilson', 'forget', ' ...

# %%
#check to see if I can look up a word from count vect
# matrix which is in a particular document. Yes!
type(count_vect.vocabulary_)
for key in count_vect.vocabulary_.keys():
    if count_vect.vocabulary_[key]==2323:
        print(key)
# Out:
# sequels

# %%
# stop words currently in "english". Could add to this 
# list later.
count_vect.get_stop_words()
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'do',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fifty',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'keep',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'rather',
#            're',
#            'same',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves'})

# %%
#Convert from sparse array to numpy array
X_train_counts
X_train_counts_arr = X_train_counts.toarray()
type(X_train_counts_arr[0][0])
# Out:
# numpy.int64

# %%
# getting indices of features in matrix for doc1
type(X_train_counts_arr)
ind = X_train_counts[0].nonzero()
ind[1]
# Out:
# array([1486,  982, 1958, 2182, 1564, 1978, 1640, 2087,  122,  755],
#       dtype=int32)

# %%
# showing words in doc 1 that are represented in counts matrix
type(count_vect.vocabulary_)
for key in count_vect.vocabulary_.keys():
    if count_vect.vocabulary_[key] in ind[1]:
        print(key)
# Out:
# doesn
# answer
# questions
# makes
# point
# like
# rest
# planet
# far
# kingdom

# %% [markdown]
#  do I want to stem or lemmatize?
#  much adieu about nothing!!!  However, I do want to take out the numbers...they are driving me crazy....regex to the rescue. Also, why doesn't peace show up in doc 1?

# %%
from nltk.tokenize import word_tokenize, wordpunct_tokenize, RegexpTokenizer

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

# %%
# 1. Create a set of documents.
#corpus = [' '.join(df_quick['Review']).lower() for row in df_quick]
#print(corpus)

# %%
df_corpus = df_quick["Review"].str.replace(r'([^a-zA-Z\s]+?)'," ")
bag_of_words = " ".join(df_corpus)
bag_of_words.lower()
df_corpus =df_corpus.str.lower()

# %%
# 2. Create a set of tokenized documents.
docs_tokenized = [word_tokenize(content) for content in df_corpus]
#docs_tokenized

# %%
# 3. Strip out stop words from each tokenized document.
stop = set(stopwords.words('english'))
docs_stop = [[word for word in words if word not in stop] for words in docs_tokenized]
#docs_stop

# %%
# Stemming / Lemmatization

# 1. Stem using both stemmers and the lemmatizer
porter = PorterStemmer()
snowball = SnowballStemmer('english')
wordnet = WordNetLemmatizer()
docs_porter = [[porter.stem(word) for word in words] for words in docs_stop]
docs_snowball = [[snowball.stem(word) for word in words] for words in docs_stop]
docs_wordnet = [[wordnet.lemmatize(word) for word in words] for words in docs_stop]
#docs_wordnet

# %%
docs_wordnet
new_element =[]
for element in docs_wordnet:
    test = " ".join(element)
    new_element.append(test) 
type(new_element)
new_series = pd.Series(new_element)
new_series
col = "text"
new_df = pd.DataFrame(new_series,columns = [col])
new_df.head()
# Out:
#                                                 text
# 0  manakamana answer question yet make point nepa...
# 1  wilfully offensive powered chest thumping mach...
# 2  would difficult imagine material wrong spade l...
# 3  despite gusto star brings role hard ride shotg...
# 4  good idea core film buried unsightly pile flat...

# %% [markdown]
# Now, I have a dataframe with a really good stemmed and cleaned text. Let's get the official countvectorized matrix and take a look at it.

# %%
cv = CountVectorizer(lowercase=True, tokenizer=None, strip_accents= "ascii", stop_words="english",
                             analyzer='word', max_df=1.0, min_df=2,ngram_range=(1,1),
                             max_features=3000)
X_train_counts_final = cv.fit_transform(new_df.text.values)
X_train_counts_final
X_train_counts_final_arr = X_train_counts_final.toarray()
X_train_counts_final_arr.shape
# Out:
# (20000, 3000)

# %%
stop_words = set(stopwords.words('english'))
stop_words
#new_stopwords = set(["film","movie","like","feel","time","little","adject", "adds",
#                   "bestloved","agonizingly","bantamweight"])
#new_stopwords
#stop_words.update(new_stopwords)
for word in stop_words:
    print(word)
# Out:
# other
# itself
# between
# all
# she
# ve
# before
# needn
# her
# through
# below
# own
# couldn
# don
# ourselves
# during
# does
# you're
# why
# should've
# y
# mightn
# haven't
# isn't
# so
# wasn
# this
# again
# but
# each
# into
# couldn't
# aren
# nor
# how
# your
# mightn't
# mustn't
# be
# up
# any
# no
# been
# out
# under
# here
# my
# you'd
# ll
# hasn
# most
# don't
# wasn't
# them
# mustn
# having
# their
# they
# being
# it's
# ain
# by
# did
# further
# only
# yourselves
# its
# am
# too
# hadn't
# just
# his
# over
# once
# for
# shan't
# shouldn't
# weren
# she's
# then
# t
# above
# won
# in
# needn't
# o
# do
# very
# as
# are
# whom
# after
# few
# of
# from
# him
# d
# those
# hadn
# isn
# himself
# doesn
# now
# when
# he
# because
# on
# didn
# same
# that'll
# were
# myself
# should
# shan
# s
# aren't
# that
# until
# it
# some
# the
# haven
# which
# doing
# didn't
# or
# i
# ours
# m
# won't
# hasn't
# such
# weren't
# themselves
# if
# where
# can
# you
# there
# these
# herself
# me
# re
# you'll
# off
# has
# than
# wouldn
# you've
# what
# wouldn't
# to
# yours
# theirs
# hers
# will
# shouldn
# yourself
# both
# with
# doesn't
# and
# is
# about
# at
# down
# a
# against
# our
# an
# not
# ma
# had
# we
# while
# more
# have
# who
# was

# %%
feature_names2 = cv.get_feature_names()
#feature_names2

# %%
#create bag of words dictionary to get lookup table
# for words in matrix
for key in sorted(cv.vocabulary_.keys()):
    print("{0:<20s} {1}".format(key, cv.vocabulary_[key]))
# Out:
# abandon              0
# ability              1
# able                 2
# absence              3
# absent               4
# absolute             5
# absolutely           6
# absorbing            7
# absurd               8
# absurdity            9
# abuse                10
# academy              11
# accent               12
# accessible           13
# accomplished         14
# accomplishment       15
# account              16
# accurate             17
# achieve              18
# achieved             19
# achievement          20
# achieves             21
# act                  22
# acted                23
# acting               24
# action               25
# actioner             26
# activity             27
# actor                28
# actress              29
# actual               30
# actually             31
# ad                   32
# adam                 33
# adaptation           34
# add                  35
# added                36
# adding               37
# addition             38
# address              39
# adequate             40
# admirable            41
# admire               42
# admit                43
# adolescence          44
# adolescent           45
# adult                46
# advance              47
# adventure            48
# aesthetic            49
# affair               50
# affecting            51
# affection            52
# affleck              53
# afraid               54
# african              55
# afternoon            56
# age                  57
# aged                 58
# agenda               59
# agent                60
# aggressively         61
# ago                  62
# ahead                63
# aim                  64
# aimed                65
# air                  66
# al                   67
# ala                  68
# albeit               69
# alice                70
# alien                71
# alike                72
# alive                73
# allegory             74
# allen                75
# allow                76
# allowed              77
# allowing             78
# allows               79
# altogether           80
# amazing              81
# ambiguity            82
# ambiguous            83
# ambition             84
# ambitious            85
# america              86
# american             87
# amiable              88
# amid                 89
# amusement            90
# amusing              91
# amy                  92
# anchored             93
# anderson             94
# andrew               95
# angel                96
# angeles              97
# anger                98
# angle                99
# angry                100
# angst                101
# animal               102
# animated             103
# animation            104
# anna                 105
# annoying             106
# anonymous            107
# answer               108
# anthony              109
# anti                 110
# antic                111
# anxiety              112
# anybody              113
# apart                114
# apatow               115
# ape                  116
# apocalypse           117
# wilson               2938
# win                  2939
# wind                 2940
# window               2941
# wink                 2942
# winner               2943
# winning              2944
# winter               2945
# wisdom               2946
# wise                 2947
# wish                 2948
# wishing              2949
# wit                  2950
# witch                2951
# witherspoon          2952
# witless              2953
# witness              2954
# witty                2955
# woefully             2956
# wolf                 2957
# wolverine            2958
# woman                2959
# wonder               2960
# wonderful            2961
# wonderfully          2962
# wondering            2963
# woo                  2964
# wood                 2965
# wooden               2966
# woody                2967
# word                 2968
# work                 2969
# worked               2970
# working              2971
# world                2972
# worn                 2973
# worse                2974
# worst                2975
# worth                2976
# worthwhile           2977
# worthy               2978
# wrap                 2979
# wrapped              2980
# wreck                2981
# wrenching            2982
# wright               2983
# write                2984
# writer               2985
# writing              2986
# written              2987
# wrong                2988
# wrote                2989
# yarn                 2990
# year                 2991
# yes                  2992
# york                 2993
# young                2994
# younger              2995
# youth                2996
# zero                 2997
# zombie               2998
# zone                 2999

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf_transformer = TfidfTransformer(use_idf=True)
tfidf_transformer.fit(X_train_counts)
X_train_tfidf = tfidf_transformer.transform(X_train_counts)
X_train_tfidf_arr = X_train_tfidf.toarray()

# %%
type(X_train_tfidf_arr)
# Out:
# numpy.ndarray

# %%
from collections import Counter, defaultdict

import seaborn as sns
sns.set(style="darkgrid")
sns.set(font_scale=1.3)

# %%
df_pos = new_df[df_quick["Freshness"]==1]
df_pos
X_train_counts_pos = cv.transform(df_pos["text"].values)
word_freq_pos = dict(zip(cv.get_feature_names(), np.asarray(X_train_counts_pos.sum(axis=0)).ravel()))
word_counter_pos = Counter(word_freq_pos)
word_counter_df_pos = pd.DataFrame(word_counter_pos.most_common(20), columns = ['word', 'freq'])
df_neg = new_df[df_quick["Freshness"]==0]
X_train_counts_neg = cv.transform(df_neg["text"].values)
word_freq_neg = dict(zip(count_vect.get_feature_names(), np.asarray(X_train_counts_neg.sum(axis=0)).ravel()))
word_counter_neg = Counter(word_freq_neg)
word_counter_df_neg = pd.DataFrame(word_counter_neg.most_common(20), columns = ['word', 'freq'])

fig, ax = plt.subplots(figsize=(12, 10))
#plt.subplot(1,2,1)
sns.barplot(x="word", y="freq", data=word_counter_df_pos, palette="PuBuGn_d", ax=ax)
#plt.subplot(1,2,2)
#ax[0,1]= sns.barplot(x="word", y="freq", data=word_counter_df_neg, palette="PuBuGn_d", ax=ax)
plt.xlabel("Word", fontsize=16, fontweight ="bold")
plt.ylabel("Frequency of Word",fontsize = 16,fontweight="bold")
plt.xticks(rotation=45)
plt.title("Most Common Words in Positve Reviews",fontsize=20)
plt.savefig("images/most_common_words_pos")
plt.show();

# %%
fig, ax = plt.subplots(figsize=(12, 10))
#plt.subplot(1,2,1)
sns.barplot(x="word", y="freq", data=word_counter_df_neg, palette="PuBuGn_d", ax=ax)
#plt.subplot(1,2,2)
#ax[0,1]= sns.barplot(x="word", y="freq", data=word_counter_df_neg, palette="PuBuGn_d", ax=ax)
plt.xticks(rotation=45)
plt.xlabel("Word",fontsize =16, fontweight="bold")
plt.ylabel("Frequency",fontsize =16, fontweight="bold")
plt.title("Most Common Words in Negative Reviews",fontsize=20)
plt.savefig("images/most_common_words_neg")
plt.show();

# %%
from os import path
#from PIL import image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %%
df_neg.head()
temp = df_neg["text"].values
text= " ".join(review for review in temp)
stopwords = set(STOPWORDS)
wordcloud =WordCloud(width=1600, height=800, stopwords=stopwords,background_color="white").generate(text)
fig = plt.figure(figsize = (9,6),facecolor="w")
plt.axis("off")
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.tight_layout(pad=0)
#plt.title("Word Cloud for Positive Reviews", fontsize=20)
plt.savefig("images/word_cloud4.png",facecolor="w")
plt.show()

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
# print('\nTraining a Naive Bayes model.')
nb_model = MultinomialNB(alpha=1.0, fit_prior=False, class_prior=None)
y=df_quick["Freshness"].values
nb_model.fit(X_train_tfidf_arr, y)
type(X_train_tfidf_arr)
# Out:
# numpy.ndarray

# %%
ind_max = nb_model.feature_log_prob_.argsort()[::-1]
ind_max
ind_top = ind_max[:,:100]
ind_top.shape
feature_names_neg = cv.get_feature_names(ind_top[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-0a82688fff26> in <module>
#       3 ind_top = ind_max[:,:100]
#       4 ind_top.shape
# ----> 5 feature_names_neg = cv.get_feature_names(ind_top[0])
#
# TypeError: get_feature_names() takes 1 positional argument but 2 were given

# %%
df_test = df[40000:42500]
y_test = df_test["Freshness"].values
X_test = df_test["Review"].values
df_corpus_test = df_test["Review"].str.replace(r'([^a-zA-Z\s]+?)'," ")
bag_of_words = " ".join(df_corpus)
df_corpus_test =df_corpus_test.str.lower()
docs_tokenized_test = [word_tokenize(content) for content in df_corpus_test]
docs_stop_test = [[word for word in words if word not in stop] for words in docs_tokenized_test]
docs_wordnet_test = [[wordnet.lemmatize(word) for word in words] for words in docs_stop_test]
docs_wordnet_test
# Out:
# [['exultant', 'comedy', 'american', 'repression', 'revolt'],
#  ['moving', 'term', 'invigorating', 'conversation', 'starter'],
#  ['bullett',
#   'raja',
#   'director',
#   'tigmanshu',
#   'dhulia',
#   'commercial',
#   'film',
#   'yet',
#   'weakest'],
#  ['infinitely',
#   'polar',
#   'bear',
#   'vivid',
#   'snapshot',
#   'one',
#   'family',
#   'surviving',
#   'state',
#   'chaotic',
#   'affectionate',
#   'imperfection',
#   'time',
#   'kid',
#   'raising',
#   'seen',
#   'neglect',
#   'normal'],
#  ['disney',
#   'pixar',
#   'animation',
#   'quality',
#   'especially',
#   'appearance',
#   'human',
#   'lively',
#   'fantasy',
#   'pack',
#   'enough',
#   'tropical',
#   'incident',
#   'vivid',
#   'action',
#   'pas',
#   'muster'],
#  ['de', 'bont', 'simply', 'reprises', 'first', 'film'],
#  ['least',
#   'cinematic',
#   'train',
#   'look',
#   'pretty',
#   'run',
#   'track',
#   'driving',
#   'home',
#   'symbolism',
#   'people',
#   'theater',
#   'full',
#   'content',
#   'review',
#   'parent',
#   'violence',
#   'profanity',
#   'nudity',
#   'etc',
#   'also',
#   'available'],
#  ['performance',
#   'make',
#   'material',
#   'human',
#   'accessible',
#   'mainly',
#   'film',
#   'brave',
#   'young',
#   'star',
#   'summer',
#   'bishil'],
#  ['filmmaker',
#   'possessed',
#   'mutation',
#   'travel',
#   'back',
#   'time',
#   'make',
#   'different',
#   'movie',
#   'smart',
#   'fun',
#   'like',
#   'last',
#   'two',
#   'film',
#   'rather',
#   'labored',
#   'cliched'],
#  ['helen',
#   'mirren',
#   'commanding',
#   'performance',
#   'elizabeth',
#   'ii',
#   'richly',
#   'rewarding',
#   'allowing',
#   'multitude',
#   'angle',
#   'ridicule',
#   'empathy'],
#  ['robert',
#   'zemeckis',
#   'walk',
#   'breathtaking',
#   'hope',
#   'film',
#   'man',
#   'walking',
#   'wire',
#   'world',
#   'trade',
#   'center',
#   'tower'],
#  ['dark',
#   'shadow',
#   'amusing',
#   'fit',
#   'spurt',
#   'sure',
#   'make',
#   'ton',
#   'money',
#   'terribly',
#   'familiar',
#   'fatigued'],
#  ['saul',
#   'dibb',
#   'foamy',
#   'adaptation',
#   'amanda',
#   'foreman',
#   'georgiana',
#   'duchess',
#   'devonshire',
#   'focus',
#   'soft',
#   'soap',
#   'attention',
#   'much',
#   'leading',
#   'lady',
#   'personal',
#   'struggle',
#   'leaf',
#   'story',
#   'broiling',
#   'th',
#   'century',
#   'political',
#   'social',
#   'context'],
#  ['anders',
#   'danielsen',
#   'lie',
#   'give',
#   'compelling',
#   'deep',
#   'etched',
#   'lead',
#   'turn',
#   'find',
#   'drawn',
#   'search',
#   'reason',
#   'continue',
#   'living'],
#  ['actor',
#   'support',
#   'translates',
#   'screen',
#   'real',
#   'communion',
#   'musical',
#   'performance',
#   'together',
#   'film',
#   'highlight'],
#  ['surprisingly',
#   'subtle',
#   'take',
#   'aging',
#   'changing',
#   'role',
#   'relationship'],
#  ['arguably',
#   'spin',
#   'control',
#   'last',
#   'act',
#   'overall',
#   'make',
#   'wild',
#   'ride',
#   'provides',
#   'sort',
#   'juice',
#   'expect',
#   'top',
#   'line',
#   'muscle',
#   'car'],
#  ['movie',
#   'think',
#   'tomik',
#   'pretty',
#   'sick',
#   'puppy',
#   'kieslowski',
#   'skill',
#   'spare',
#   'cerebral',
#   'film',
#   'maker',
#   'turn',
#   'perception',
#   'around'],
#  ['full',
#   'insanely',
#   'grand',
#   'passion',
#   'bloodthirsty',
#   'violence',
#   'jet',
#   'black',
#   'comedy',
#   'sadistic',
#   'masterpiece',
#   'confirms',
#   'korea',
#   'current',
#   'status',
#   'producer',
#   'world',
#   'exciting',
#   'cinema'],
#  ['movie',
#   'raw',
#   'ambition',
#   'spirit',
#   'literally',
#   'reinvents',
#   'standard',
#   'everything',
#   'associated'],
#  ['yes',
#   'absolutely',
#   'fun',
#   'well',
#   'many',
#   'many',
#   'thing',
#   'go',
#   'boom',
#   'amid',
#   'atmospheric',
#   'urban',
#   'jungle'],
#  ['another',
#   'sure',
#   'fire',
#   'cult',
#   'hit',
#   'mancini',
#   'take',
#   'chucky',
#   'terrifying',
#   'new',
#   'height',
#   'even',
#   'missing',
#   'ending',
#   'deserves'],
#  ['deliberately',
#   'old',
#   'fashioned',
#   'ww',
#   'adventure',
#   'shine',
#   'light',
#   'little',
#   'known',
#   'chapter',
#   'war',
#   'never',
#   'cease',
#   'entertain'],
#  ['extraordinary',
#   'magical',
#   'wondrous',
#   'blessedly',
#   'original',
#   'animated',
#   'movie',
#   'experience',
#   'everyone'],
#  ['w', 'fail', 'drama', 'comedy', 'unclear', 'sequence', 'meant'],
#  ['miss',
#   'sloane',
#   'heroine',
#   'driven',
#   'craftiness',
#   'film',
#   'subtlety',
#   'hammer',
#   'repeatedly',
#   'hitting',
#   'anvil'],
#  ['facial',
#   'jewellery',
#   'elvis',
#   'costello',
#   'music',
#   'cell',
#   'phone',
#   'notwithstanding',
#   'keep',
#   'expecting',
#   'people',
#   'challenge',
#   'duel',
#   'rapier',
#   'dawn'],
#  ['film', 'effective', 'need', 'equalizer', 'line', 'see', 'find'],
#  ['lifeless',
#   'number',
#   'production',
#   'excruciating',
#   'exercise',
#   'cliche',
#   'tedium',
#   'sole',
#   'joy',
#   'trying',
#   'figure',
#   'lead',
#   'overacting'],
#  ['predator',
#   'gut',
#   'slash',
#   'way',
#   'gory',
#   'sci',
#   'fi',
#   'mediocrity',
#   'failed',
#   'abysmal',
#   'pacing',
#   'loses',
#   'character',
#   'subplots',
#   'interest',
#   'along',
#   'way'],
#  ['fairly', 'unconvincing', 'heart', 'roughly', 'right', 'place'],
#  ['hard',
#   'say',
#   'whether',
#   'mendes',
#   'egger',
#   'complement',
#   'weak',
#   'spot',
#   'one',
#   'manages',
#   'bring',
#   'best',
#   'collaborator',
#   'ultimately',
#   'matter',
#   'even',
#   'fan',
#   'either',
#   'give',
#   'away',
#   'go',
#   'shot'],
#  ['mendes',
#   'working',
#   'script',
#   'husband',
#   'wife',
#   'hipster',
#   'dave',
#   'egger',
#   'vendela',
#   'vida',
#   'end',
#   'thing',
#   'vaguely',
#   'haunting',
#   'way',
#   'without',
#   'really',
#   'resolving',
#   'good',
#   'thing'],
#  ['thematically',
#   'though',
#   'improvement',
#   'forebear',
#   'mainly',
#   'due',
#   'way',
#   'deal',
#   'much',
#   'like',
#   'scorsese',
#   'best',
#   'work',
#   'archaic',
#   'nature',
#   'criminal',
#   'set'],
#  ['problem',
#   'try',
#   'stuff',
#   'romantic',
#   'comedy',
#   'episodic',
#   'even',
#   'adventure',
#   'mystery',
#   'story',
#   'trunk',
#   'taxi',
#   'gibraltar',
#   'full',
#   'review',
#   'spanish'],
#  ['le', 'fantastic'],
#  ['film',
#   'belongs',
#   'noble',
#   'heritage',
#   'beery',
#   'dvd',
#   'night',
#   'takeaway',
#   'themed',
#   'movie',
#   'double',
#   'bill'],
#  ['stumbling',
#   'romantic',
#   'lark',
#   'bubbly',
#   'psychic',
#   'throw',
#   'shrill',
#   'ghost',
#   'boyfriend',
#   'former',
#   'fiancee',
#   'dead',
#   'body',
#   'stiff',
#   'supernatural',
#   'comedy'],
#  ['world', 'war', 'ii', 'movie', 'dad', 'fall', 'asleep', 'watching', 'couch'],
#  ['well',
#   'crafted',
#   'bravely',
#   'revealing',
#   'little',
#   'film',
#   'could',
#   'considered',
#   'essential',
#   'education',
#   'baseball',
#   'fan'],
#  ['poor',
#   'man',
#   'sweet',
#   'hereafter',
#   'feature',
#   'amy',
#   'morton',
#   'strong',
#   'performance',
#   'poorly',
#   'photographed',
#   'occasionally',
#   'incomprehensible',
#   'dialogue'],
#  ['contain',
#   'exactly',
#   'two',
#   'memorable',
#   'scene',
#   'rest',
#   'rocknrolla',
#   'one',
#   'identical',
#   'scene',
#   'another',
#   'one',
#   'guy',
#   'try',
#   'badass',
#   'guy'],
#  ['le', 'shocking', 'utterly', 'boring'],
#  ['film', 'tale', 'youthful', 'innocence', 'mature', 'disillusionment'],
#  ['depressing',
#   'thing',
#   'feckless',
#   'ugly',
#   'pointless',
#   'film',
#   'edgy',
#   'insightful',
#   'aim'],
#  ['little',
#   'grungy',
#   'looking',
#   'tv',
#   'movie',
#   'week',
#   'pointless',
#   'gore',
#   'tossed'],
#  ['odd',
#   'quasi',
#   'mystical',
#   'movie',
#   'silly',
#   'adult',
#   'take',
#   'seriously',
#   'frankly',
#   'weird',
#   'kid'],
#  ['irresistible',
#   'combination',
#   'rousing',
#   'good',
#   'story',
#   'set',
#   'truly',
#   'grand',
#   'scale'],
#  ['stunning', 'baffling', 'pretentious', 'brilliant', 'life'],
#  ['penn',
#   'main',
#   'idea',
#   'going',
#   'native',
#   'making',
#   'eye',
#   'contact',
#   'deer'],
#  ['girl',
#   'played',
#   'fire',
#   'nearly',
#   'admirable',
#   'dragon',
#   'tattoo',
#   'ultimately',
#   'save',
#   'film',
#   'however',
#   'quality',
#   'time',
#   'allows',
#   'u',
#   'spend',
#   'girl'],
#  ['marie',
#   'curie',
#   'get',
#   'look',
#   'right',
#   'costume',
#   'creation',
#   'early',
#   'th',
#   'century',
#   'parisian',
#   'street',
#   'classroom',
#   'film',
#   'lifeless'],
#  ['interested',
#   'weird',
#   'good',
#   'aggressively',
#   'obnoxious',
#   'comedy',
#   'putting',
#   'amusing'],
#  ['problem',
#   'hall',
#   'pas',
#   'think',
#   'owen',
#   'wilson',
#   'jason',
#   'sudeikis',
#   'affable',
#   'movie',
#   'want',
#   'u',
#   'like'],
#  ['occasionally', 'incoherent', 'often', 'audacious', 'dazzling'],
#  ['stone',
#   'portrait',
#   'george',
#   'bush',
#   'laid',
#   'trowel',
#   'maybe',
#   'god',
#   'seems',
#   'engineered',
#   'real',
#   'bush',
#   'life',
#   'similarly',
#   'crude',
#   'sense',
#   'irony'],
#  ['expect',
#   'thriller',
#   'seat',
#   'edge',
#   'sense',
#   'thrilled',
#   'repulsed',
#   'bold',
#   'faithful',
#   'adaptation',
#   'ballard',
#   'ever',
#   'prescient',
#   'picture',
#   'first',
#   'world',
#   'strife'],
#  ['little',
#   'prehistoric',
#   'epic',
#   'could',
#   'actually',
#   'delivers',
#   'entertaining',
#   'couple',
#   'hour'],
#  ['bunch',
#   'creator',
#   'david',
#   'alaux',
#   'eric',
#   'tosti',
#   'jean',
#   'francois',
#   'tosti',
#   'come',
#   'intergenerational',
#   'animated',
#   'action',
#   'movie',
#   'best',
#   'moment',
#   'humour'],
#  ['follows',
#   'unremittingly',
#   'pursues',
#   'two',
#   'greatest',
#   'theme',
#   'art',
#   'life',
#   'adolescent',
#   'kid',
#   'learn',
#   'stave',
#   'sex',
#   'however',
#   'temporarily',
#   'ineluctable',
#   'approach',
#   'death'],
#  ['long',
#   'actionless',
#   'slow',
#   'annoying',
#   'inscrutable',
#   'couple',
#   'thing',
#   'good',
#   'however',
#   'samantha',
#   'morton',
#   'give',
#   'fine',
#   'performance',
#   'cinematography',
#   'late',
#   'th',
#   'century',
#   'ireland',
#   'rewarding'],
#  ['movie',
#   'brimming',
#   'beautiful',
#   'people',
#   'beautiful',
#   'scenery',
#   'contagious',
#   'enthusiasm',
#   'movie',
#   'whir',
#   'sight',
#   'sound',
#   'barcelona'],
#  ['stepford', 'wife', 'terrific', 'comedy', 'lousy', 'motion', 'picture'],
#  ['courtroom',
#   'thriller',
#   'invariably',
#   'make',
#   'riveting',
#   'cinema',
#   'fade',
#   'exception',
#   'kruger',
#   'appearing',
#   'first',
#   'film',
#   'native',
#   'tongue',
#   'previously',
#   'acting',
#   'french',
#   'english',
#   'language',
#   'movie',
#   'superb'],
#  ['movie',
#   'match',
#   'quentin',
#   'tarantino',
#   'spaghetti',
#   'western',
#   'blaxploitation',
#   'southern',
#   'come',
#   'illustrating',
#   'carnage',
#   'wrought',
#   'slavery'],
#  ['utterly',
#   'charming',
#   'start',
#   'finish',
#   'well',
#   'made',
#   'smartly',
#   'written',
#   'family',
#   'adventure',
#   'infectious',
#   'sense',
#   'fun',
#   'miss'],
#  ['film',
#   'adult',
#   'enjoy',
#   'without',
#   'feeling',
#   'obligation',
#   'take',
#   'along',
#   'kid',
#   'cover'],
#  ['patriot',
#   'day',
#   'film',
#   'keep',
#   'edge',
#   'seat',
#   'full',
#   'review',
#   'spanish'],
#  ['mother',
#   'day',
#   'proposition',
#   'like',
#   'cooking',
#   'dinner',
#   'mum',
#   'making',
#   'dish'],
#  ['technically',
#   'excellent',
#   'throughout',
#   'style',
#   'strong',
#   'performance',
#   'enough',
#   'entirely',
#   'compensate',
#   'distinct',
#   'lack',
#   'narrative',
#   'purpose'],
#  ['although',
#   'strives',
#   'thought',
#   'provoking',
#   'exploration',
#   'flesh',
#   'soul',
#   'sleeping',
#   'beauty',
#   'cold',
#   'detached',
#   'make',
#   'u',
#   'care',
#   'either',
#   'way'],
#  ['dan',
#   'real',
#   'life',
#   'pretty',
#   'warm',
#   'genuine',
#   'comedy',
#   'succeeds',
#   'least',
#   'part',
#   'gutsy',
#   'casting',
#   'choice'],
#  ['great', 'fun', 'part', 'anyone'],
#  ['one',
#   'finest',
#   'film',
#   'artist',
#   'ever',
#   'made',
#   'fashioned',
#   'filmmaker',
#   'notable',
#   'artist'],
#  ['overly',
#   'long',
#   'superficial',
#   'shallow',
#   'closet',
#   'updated',
#   'sensitivity'],
#  ['wit', 'style', 'best', 'bond', 'movie'],
#  ['goodnight',
#   'mommy',
#   'brilliantly',
#   'unnerving',
#   'outset',
#   'final',
#   'act',
#   'twisted',
#   'little',
#   'treat'],
#  ['phantom',
#   'thread',
#   'delicate',
#   'story',
#   'tight',
#   'unpredictable',
#   'relationship',
#   'complex',
#   'anderson',
#   'developed',
#   'character',
#   'like',
#   'real',
#   'human',
#   'being',
#   'many',
#   'thing'],
#  ['much', 'movie', 'play', 'like', 'civics', 'lesson'],
#  ['make',
#   'original',
#   'urban',
#   'legend',
#   'look',
#   'like',
#   'alfred',
#   'hitchcock',
#   'movie',
#   'comparison'],
#  ['even',
#   'though',
#   'portends',
#   'full',
#   'twist',
#   'turn',
#   'really',
#   'going',
#   'terribly',
#   'surprised',
#   'go',
#   'time'],
#  ['step',
#   'another',
#   'vehicle',
#   'showcasing',
#   'latest',
#   'creative',
#   'street',
#   'dance',
#   'move',
#   'resign',
#   'mawkishness',
#   'get',
#   'way'],
#  ['absolutely',
#   'ingenious',
#   'know',
#   'car',
#   'car',
#   'movie',
#   'richer',
#   'experience',
#   'watching',
#   'put',
#   'pedal',
#   'metal',
#   'get',
#   'going'],
#  ['clumsiness',
#   'follows',
#   'clumsiness',
#   'acting',
#   'staging',
#   'detail',
#   'plot',
#   'reach',
#   'point',
#   'cool',
#   'indifference'],
#  ['filmmaker',
#   'yael',
#   'hersonski',
#   'reshapes',
#   'impossibly',
#   'vile',
#   'tragic',
#   'source',
#   'material',
#   'devastating',
#   'record',
#   'nazi',
#   'criminality'],
#  ['computer',
#   'chess',
#   'open',
#   'many',
#   'interpretation',
#   'great',
#   'bujalski',
#   'explain',
#   'summer',
#   'filled',
#   'numbingly',
#   'repetitive',
#   'entertainment',
#   'extraordinary',
#   'movie',
#   'invite',
#   'viewer',
#   'think'],
#  ['thor',
#   'ragnarok',
#   'fun',
#   'thor',
#   'movie',
#   'long',
#   'shot',
#   'still',
#   'much',
#   'thor',
#   'movie',
#   'better',
#   'worse'],
#  ['might',
#   'leigh',
#   'worst',
#   'film',
#   'worst',
#   'thing',
#   'ever',
#   'say',
#   'film',
#   'filmmaker',
#   'efficient',
#   'prolific',
#   'leigh',
#   'disappointing'],
#  ['eminem',
#   'manages',
#   'take',
#   'think',
#   'know',
#   'eminem',
#   'inject',
#   'character',
#   'without',
#   'turning',
#   'character',
#   'simple',
#   'screen',
#   'version'],
#  ['end',
#   'outgrown',
#   'unassuming',
#   'premise',
#   'taken',
#   'audience',
#   'emotional',
#   'journey',
#   'affecting',
#   'serendipitous',
#   'nature'],
#  ['novelty', 'quickly', 'fade', 'since', 'guessed', 'story'],
#  ['film',
#   'let',
#   'overlong',
#   'running',
#   'time',
#   'prurient',
#   'attempt',
#   'crowbar',
#   'emotional',
#   'response',
#   'taciturn',
#   'williams'],
#  ['saoirse',
#   'ronan',
#   'creates',
#   'unforgettable',
#   'character',
#   'full',
#   'review',
#   'spanish'],
#  ['apatow',
#   'got',
#   'gift',
#   'writing',
#   'every',
#   'character',
#   'film',
#   'deeper',
#   'expected',
#   'supporting',
#   'cast',
#   'really',
#   'get',
#   'chance',
#   'shine'],
#  ['depp',
#   'subtly',
#   'winning',
#   'man',
#   'child',
#   'oblivious',
#   'pent',
#   'rage',
#   'performance',
#   'take',
#   'breath',
#   'away',
#   'dicaprio'],
#  ['beastly',
#   'quite',
#   'cover',
#   'even',
#   'monstrous',
#   'gruesome',
#   'grotesque',
#   'come',
#   'close'],
#  ['oda',
#   'la',
#   'inocencia',
#   'de',
#   'la',
#   'ni',
#   'ez',
#   'la',
#   'aventura',
#   'de',
#   'la',
#   'juventud',
#   'la',
#   'majestuosidad',
#   'del',
#   'universo',
#   'la',
#   'magia',
#   'que',
#   'envuelve',
#   'los',
#   'j',
#   'venes',
#   'de',
#   'coraz',
#   'n'],
#  ['motivation',
#   'earnest',
#   'handsome',
#   'well',
#   'acted',
#   'unenlightening',
#   'workaday',
#   'j',
#   'edgar'],
#  ['film',
#   'starring',
#   'two',
#   'list',
#   'comedienne',
#   'least',
#   'funny',
#   'snatched',
#   'fails',
#   'count',
#   'also',
#   'seems',
#   'ambition',
#   'talented',
#   'cast',
#   'crew',
#   'make',
#   'film',
#   'come',
#   'together',
#   'real',
#   'shame'],
#  ['handsome', 'professional', 'dutiful', 'never', 'feel', 'inspired'],
#  ['ferocious',
#   'lead',
#   'performance',
#   'create',
#   'mesmerizing',
#   'power',
#   'struggle',
#   'teacher',
#   'pupil',
#   'unsettling',
#   'thrilling'],
#  ['love',
#   'grown',
#   'ups',
#   'may',
#   'feel',
#   'seen',
#   'lot',
#   'especially',
#   'caribou',
#   'stampede',
#   'shameless',
#   'pinch',
#   'lion',
#   'king'],
#  ['speaks', 'volume', 'silence', 'lingers', 'memory', 'long', 'watching'],
#  ['movie',
#   'lightliness',
#   'stay',
#   'one',
#   'given',
#   'intelligence',
#   'maker',
#   'could'],
#  ['sheer',
#   'warmth',
#   'likability',
#   'good',
#   'natured',
#   'documentary',
#   'heart',
#   'real',
#   'life',
#   'full',
#   'monty',
#   'billy',
#   'elliot',
#   'pride'],
#  ['vhs',
#   'viral',
#   'manages',
#   'improve',
#   'upon',
#   'predecessor',
#   'structure',
#   'format',
#   'however',
#   'term',
#   'scare',
#   'tale',
#   'intrigue',
#   'tale',
#   'horror'],
#  ['intelligent', 'old', 'fashioned', 'nail', 'biter'],
#  ['conclusion',
#   'film',
#   'still',
#   'difficult',
#   'follow',
#   'without',
#   'satisfying',
#   'ending',
#   'left',
#   'compelling',
#   'set',
#   'charismatic',
#   'cast',
#   'character',
#   'sketch',
#   'war',
#   'criminal',
#   'hiding'],
#  ['lobster', 'like', 'crustacean', 'delivered', 'segment'],
#  ['story',
#   'complete',
#   'end',
#   'volume',
#   'ii',
#   'many',
#   'heady',
#   'pleasure',
#   'volume',
#   'stand',
#   'little',
#   'better'],
#  ['parker',
#   'anti',
#   'carrie',
#   'bradshaw',
#   'messiness',
#   'coupled',
#   'horse',
#   'like',
#   'grin',
#   'sentimental',
#   'overcooked',
#   'know',
#   'get',
#   'away'],
#  ['work',
#   'painstaking',
#   'part',
#   'feel',
#   'pain',
#   'taken',
#   'achieve',
#   'marveled'],
#  ['beautifully',
#   'played',
#   'whole',
#   'cast',
#   'five',
#   'shibatas',
#   'tiny',
#   'sasaki',
#   'yuri',
#   'even',
#   'bit',
#   'actor',
#   'one',
#   'line',
#   'koreeda',
#   'hoped',
#   'family',
#   'whatever',
#   'form',
#   'might',
#   'take'],
#  ['composed',
#   'subtlety',
#   'jack',
#   'hammer',
#   'narrated',
#   'fantasy',
#   'seems',
#   'incapable',
#   'grandeur',
#   'magic',
#   'reducing',
#   'idea',
#   'visuals',
#   'performance',
#   'kitsch'],
#  ['welter',
#   'dissonant',
#   'intention',
#   'film',
#   'fails',
#   'seamlessly',
#   'intertwine',
#   'element',
#   'realism',
#   'fantasy'],
#  ['missing',
#   'vicky',
#   'cristina',
#   'barcelona',
#   'keenly',
#   'complex',
#   'touch',
#   'elevated',
#   'woody',
#   'allen',
#   'earlier',
#   'statement',
#   'caprice',
#   'gone',
#   'movie',
#   'year',
#   'vain',
#   'hope',
#   'thinking',
#   'iberia',
#   'would',
#   'inspire'],
#  ['movie',
#   'dennis',
#   'quaid',
#   'holding',
#   'basset',
#   'hound',
#   'ear',
#   'keep',
#   'water',
#   'bowl',
#   'pouring',
#   'coffee',
#   'bad',
#   'jaw',
#   'come',
#   'pretty',
#   'close'],
#  ['difficult', 'film', 'like', 'impossible', 'one', 'grudgingly', 'admire'],
#  ['stop',
#   'pounding',
#   'heart',
#   'becomes',
#   'sensitive',
#   'lovingly',
#   'crafted',
#   'illustration',
#   'relationship',
#   'culture',
#   'faith',
#   'identity'],
#  ['story',
#   'whose',
#   'appeal',
#   'hinge',
#   'saving',
#   'grace',
#   'getting',
#   'purpose',
#   'driven',
#   'life',
#   'one',
#   'got',
#   'remarkably',
#   'little'],
#  ['ultimately', 'feel', 'bloated', 'overlong', 'subpar', 'predecessor'],
#  ['let', 'one', 'go', 'voicemail', 'watch', 'instead'],
#  ['story',
#   'essentially',
#   'stop',
#   'moving',
#   'midway',
#   'going',
#   'occur',
#   'term',
#   'building',
#   'true',
#   'dramatic',
#   'tension',
#   'already',
#   'happened',
#   'point'],
#  ['equally', 'bloated', 'scatterbrained'],
#  ['entirely',
#   'free',
#   'ludicrous',
#   'ponderousness',
#   'damaged',
#   'prometheus',
#   'chronology',
#   'epic',
#   'convoluted',
#   'hardcore',
#   'fan',
#   'could',
#   'make',
#   'proper',
#   'sense',
#   'yet',
#   'still',
#   'scary',
#   'sort'],
#  ['cloud',
#   'atlas',
#   'never',
#   'boring',
#   'tykwer',
#   'wachowskis',
#   'make',
#   'virtue',
#   'everything',
#   'unexplained',
#   'creating',
#   'genuine',
#   'awe',
#   'mystery'],
#  ['dear',
#   'white',
#   'people',
#   'biggest',
#   'flaw',
#   'excessive',
#   'ambition',
#   'problem',
#   'movie',
#   'could',
#   'stand'],
#  ['service',
#   'turn',
#   'find',
#   'filmmaker',
#   'hidden',
#   'narrative',
#   'riddle',
#   'pretty',
#   'well',
#   'executed',
#   'one',
#   'said',
#   'done',
#   'terribly',
#   'memorable',
#   'one',
#   'either'],
#  ['honestly',
#   'know',
#   'say',
#   'movie',
#   'feel',
#   'phenomenally',
#   'old',
#   'fashioned',
#   'outdated',
#   'ridiculously',
#   'conservative',
#   'undermining',
#   'female',
#   'independence'],
#  ['brash',
#   'departure',
#   'legend',
#   'retains',
#   'round',
#   'table',
#   'still',
#   'contemporary',
#   'echo',
#   'make',
#   'dark',
#   'age',
#   'relevant',
#   'movie',
#   'longwinded',
#   'part',
#   'overcomes',
#   'shortcoming'],
#  ['audience',
#   'seeking',
#   'polished',
#   'vacuous',
#   'grand',
#   'scale',
#   'spectacle',
#   'become',
#   'synonymous',
#   'series',
#   'director',
#   'transformer',
#   'age',
#   'extinction',
#   'give',
#   'series',
#   'new',
#   'lease',
#   'life'],
#  ['luminous',
#   'magical',
#   'movie',
#   'dazzle',
#   'even',
#   'fantasy',
#   'film',
#   'phobic'],
#  ['might', 'give', 'restless', 'night', 'fell', 'asleep', 'theater'],
#  ['many',
#   'thing',
#   'left',
#   'unexplained',
#   'end',
#   'world',
#   'greater',
#   'sense',
#   'panic',
#   'internet',
#   'still',
#   'running',
#   'smoothly',
#   'one',
#   'guy',
#   'want',
#   'everything',
#   'fit',
#   'place',
#   'end'],
#  ['hacksaw',
#   'ridge',
#   'movie',
#   'anyone',
#   'felt',
#   'like',
#   'outcast',
#   'capture',
#   'feeling',
#   'defend',
#   'one',
#   'value',
#   'stand',
#   'one',
#   'conviction',
#   'looking',
#   'left',
#   'everyone',
#   'telling',
#   'look',
#   'right',
#   'brutal',
#   'tense'],
#  ['lucky', 'rare', 'figure', 'robot', 'fighting', 'eventually'],
#  ['walking',
#   'dinosaur',
#   'gorgeous',
#   'meticulously',
#   'detailed',
#   'cgi',
#   'also',
#   'way',
#   'many',
#   'stupid',
#   'joke',
#   'poop',
#   'puke'],
#  ['stay',
#   'seen',
#   'like',
#   'haunting',
#   'strain',
#   'music',
#   'love',
#   'song',
#   'elegy',
#   'might'],
#  ['jump',
#   'chair',
#   'scary',
#   'laugh',
#   'riot',
#   'yet',
#   'another',
#   'evil',
#   'deft',
#   'horror',
#   'comedy'],
#  ['viggo',
#   'mortensen',
#   'save',
#   'almost',
#   'anything',
#   'full',
#   'review',
#   'spanish'],
#  ['jane',
#   'eyre',
#   'instead',
#   'crimson',
#   'peak',
#   'seems',
#   'use',
#   'admittedly',
#   'smashing',
#   'costume',
#   'cover',
#   'lack',
#   'compelling',
#   'narrative'],
#  ['great', 'effect', 'bad', 'acting', 'look', 'like'],
#  ['broccoli',
#   'keep',
#   'piling',
#   'goody',
#   'lush',
#   'ken',
#   'adam',
#   'set',
#   'gadgetry',
#   'gam',
#   'galore',
#   'super',
#   'stunt',
#   'effect'],
#  ['though',
#   'movie',
#   'faint',
#   'heart',
#   'made',
#   'inventiveness',
#   'panache',
#   'somewhat',
#   'sweetens',
#   'dismayingly',
#   'dark',
#   'vision',
#   'future',
#   'explores'],
#  ['woodley', 'solid', 'performance', 'keep', 'adrift', 'steady'],
#  ['carry',
#   'residue',
#   'something',
#   'much',
#   'harsher',
#   'something',
#   'scrubbed',
#   'clean'],
#  ['revolution',
#   'dazzlingly',
#   'shot',
#   'cinematographer',
#   'bernard',
#   'lutic',
#   'process',
#   'called',
#   'system',
#   'much',
#   'visual',
#   'grandeur',
#   'seems',
#   'embarrassing',
#   'engaging',
#   'dramatic',
#   'element',
#   'mess'],
#  ['humor',
#   'quirky',
#   'personality',
#   'make',
#   'remake',
#   'enjoyable',
#   'welcomed',
#   'reboot',
#   'original'],
#  ['grim',
#   'shrill',
#   'deluded',
#   'incredibly',
#   'depressing',
#   'movie',
#   'bewilderingly',
#   'mean',
#   'spirited',
#   'trademark',
#   'farrelly',
#   'brother',
#   'gross',
#   'scene',
#   'feel',
#   'like',
#   'sweetest'],
#  ['play', 'like', 'clumsily', 'opened', 'fringe', 'theatre'],
#  ['red',
#   'riding',
#   'hood',
#   'hardwicke',
#   'might',
#   'tough',
#   'time',
#   'holding',
#   'onto',
#   'whatever',
#   'clout',
#   'left',
#   'thought',
#   'going',
#   'grandma',
#   'could',
#   'nightmare'],
#  ['new',
#   'lara',
#   'croft',
#   'reason',
#   'exist',
#   'except',
#   'first',
#   'one',
#   'made',
#   'money'],
#  ['movie',
#   'uninspired',
#   'lifeless',
#   'peter',
#   'pan',
#   'inspired',
#   'imaginative'],
#  ['spectre',
#   'far',
#   'bad',
#   'likely',
#   'frustrate',
#   'many',
#   'fan',
#   'especially',
#   'given',
#   'unenviable',
#   'position',
#   'following',
#   'heel',
#   'near',
#   'perfect',
#   'skyfall'],
#  ['new',
#   'film',
#   'keep',
#   'original',
#   'story',
#   'even',
#   'original',
#   'line',
#   'dialogue',
#   'yet',
#   'change',
#   'make',
#   'misguided'],
#  ['spite',
#   'early',
#   'disclaimer',
#   'state',
#   'book',
#   'read',
#   'adapted',
#   'film',
#   'taken',
#   'letter',
#   'editor',
#   'bild',
#   'online',
#   'glad',
#   'wnendt',
#   'company',
#   'went',
#   'ahead',
#   'anyway'],
#  ['day',
#   'succeeds',
#   'however',
#   'carrying',
#   'film',
#   'partly',
#   'sympathetic',
#   'wretchedness',
#   'partly',
#   'sheer',
#   'energy'],
#  ['weird',
#   'sci',
#   'fi',
#   'film',
#   'mix',
#   'together',
#   'animation',
#   'live',
#   'action'],
#  ['keenly',
#   'awaited',
#   'doc',
#   'love',
#   'gilda',
#   'bittersweet',
#   'portrait',
#   'gifted',
#   'comedienne',
#   'whose',
#   'death',
#   'personifies',
#   'phrase',
#   'cut',
#   'prime',
#   'li',
#   'dapolito',
#   'film',
#   'capture',
#   'wondrous',
#   'talent',
#   'innermost',
#   'thought'],
#  ['abassi',
#   'fine',
#   'job',
#   'rooting',
#   'protagonist',
#   'otherness',
#   'realistic',
#   'setting',
#   'even',
#   'start',
#   'incrementally',
#   'weaving',
#   'fantastical',
#   'element',
#   'story',
#   'always',
#   'feel',
#   'plausible'],
#  ['might',
#   'well',
#   'called',
#   'aarp',
#   'present',
#   'billy',
#   'crystal',
#   'old',
#   'going',
#   'facebooking',
#   'twittering',
#   'ipod'],
#  ['underwhelming', 'action', 'thriller', 'death', 'violence'],
#  ['beautifully',
#   'made',
#   'carefully',
#   'crafted',
#   'film',
#   'start',
#   'top',
#   'black',
#   'comedy',
#   'sizzling',
#   'snarky',
#   'satire',
#   'paint',
#   'canvas',
#   'becomes',
#   'darkly',
#   'humorous',
#   'horror',
#   'parable',
#   'painter',
#   'stalk',
#   'prey',
#   'beyond',
#   'grave'],
#  ['contrived', 'manipulative'],
#  ['high',
#   'flying',
#   'bird',
#   'unshapely',
#   'piece',
#   'storytelling',
#   'gap',
#   'plot',
#   'never',
#   'lock',
#   'rhythm',
#   'mournfulness',
#   'resentment',
#   'seep'],
#  ['berg',
#   'stick',
#   'job',
#   'hand',
#   'imagining',
#   'like',
#   'victim',
#   'sloppy',
#   'deadly',
#   'safety',
#   'practice',
#   'name',
#   'good',
#   'day',
#   'wall',
#   'street'],
#  ['going',
#   'make',
#   'anyone',
#   'forget',
#   'jaw',
#   'delivers',
#   'kind',
#   'breathless',
#   'tension',
#   'justifies',
#   'existence'],
#  ['overall',
#   'bitterness',
#   'jadedness',
#   'filmmaking',
#   'alienating',
#   'go',
#   'ahead',
#   'make',
#   'nauseating',
#   'film',
#   'please',
#   'point'],
#  ['attractive', 'adventure', 'yarn', 'combine', 'fairytale', 'western'],
#  ['entertaining',
#   'film',
#   'unfortunately',
#   'weakest',
#   'trilogy',
#   'full',
#   'review',
#   'spanish'],
#  ['inventive', 'even', 'romantic', 'woody', 'allen'],
#  ['really',
#   'want',
#   'keep',
#   'relationship',
#   'catcher',
#   'rye',
#   'sacred',
#   'see',
#   'film'],
#  ['packed',
#   'cliche',
#   'nothing',
#   'remotely',
#   'original',
#   'east',
#   'london',
#   'crime',
#   'thriller',
#   'seems',
#   'based',
#   'similar',
#   'movie',
#   'rather',
#   'original',
#   'story',
#   'character'],
#  ['story',
#   'unremarkably',
#   'formulaic',
#   'character',
#   'feel',
#   'like',
#   'stereotype'],
#  ['little',
#   'fun',
#   'mockumentary',
#   'offer',
#   'depends',
#   'falling',
#   'far',
#   'fetched',
#   'premise',
#   'america',
#   'scammed',
#   'yugoslav',
#   'space',
#   'program'],
#  ['initially',
#   'intriguing',
#   'premise',
#   'plenty',
#   'slick',
#   'production',
#   'value',
#   'suffers',
#   'style',
#   'substance',
#   'diminishing',
#   'suspense',
#   'plot',
#   'feel',
#   'bland',
#   'inane',
#   'ultimately',
#   'underwhelming'],
#  ['term',
#   'getting',
#   'message',
#   'wider',
#   'audience',
#   'film',
#   'simply',
#   'effectively',
#   'serf',
#   'part',
#   'cause'],
#  ['spectacular',
#   'failure',
#   'film',
#   'aesthetic',
#   'make',
#   'tremendous',
#   'waste',
#   'uwais',
#   'whose',
#   'talent',
#   'brawler',
#   'surpass',
#   'anything',
#   'berg',
#   'ever',
#   'disposal'],
#  ['liked',
#   'movie',
#   'know',
#   'would',
#   'liked',
#   'gone',
#   'one',
#   'step',
#   'left',
#   'slightly',
#   'disappointed'],
#  ['jackie',
#   'back',
#   'town',
#   'nice',
#   'see',
#   'something',
#   'campy',
#   'foreigner',
#   'actually',
#   'extreme',
#   'serious',
#   'fault'],
#  ['even',
#   'ace',
#   'editor',
#   'walter',
#   'murch',
#   'struggle',
#   'give',
#   'coherence',
#   'professor',
#   'fractured',
#   'episodic',
#   'journey',
#   'darkening',
#   'wartime',
#   'exile',
#   'geneva',
#   'brighter',
#   'revelation',
#   'india',
#   'sun',
#   'kissed',
#   'mediterranean'],
#  ['insider',
#   'pic',
#   'likely',
#   'produce',
#   'knowing',
#   'guffaw',
#   'industry',
#   'occasional',
#   'chuckle',
#   'john',
#   'q',
#   'public'],
#  ['mccall',
#   'high',
#   'minded',
#   'talk',
#   'seems',
#   'take',
#   'little',
#   'much',
#   'sick',
#   'glee',
#   'bloodletting',
#   'engages'],
#  ['film', 'leave', 'anyone', 'indifferent', 'full', 'review', 'spanish'],
#  ['coogler',
#   'team',
#   'conjured',
#   'universe',
#   'fleshed',
#   'player',
#   'one',
#   'existing',
#   'honestly',
#   'thriving',
#   'even',
#   'bigger',
#   'cinematic',
#   'universe',
#   'marvel'],
#  ['without',
#   'preaching',
#   'pulpit',
#   'fantastic',
#   'woman',
#   'powerfully',
#   'communicates',
#   'hostility',
#   'hatred',
#   'person',
#   'marina',
#   'encounter',
#   'simply',
#   'due',
#   'otherness'],
#  ['rare', 'comedy', 'painfully', 'unfunny', 'earns', 'single', 'laugh'],
#  ['july',
#   'provocative',
#   'honorably',
#   'independent',
#   'filmmaker',
#   'given',
#   'meager',
#   'reward',
#   'investing',
#   'time',
#   'future',
#   'worth',
#   'wait'],
#  ['even',
#   'portraying',
#   'needy',
#   'nearly',
#   'shambolic',
#   'b',
#   'atrice',
#   'midwife',
#   'm',
#   'deneuve',
#   'capable',
#   'vibrating',
#   'elegance',
#   'implies',
#   'hauteur',
#   'froideur'],
#  ['sound', 'one', 'hand', 'clasping'],
#  ['end',
#   'two',
#   'hour',
#   'minute',
#   'movie',
#   'director',
#   'sam',
#   'raimi',
#   'prof',
#   'understands',
#   'spectacle',
#   'deeper',
#   'dream',
#   'people',
#   'consume'],
#  ['competing', 'aspiration', 'movie', 'never', 'click'],
#  ['furtive',
#   'figure',
#   'history',
#   'know',
#   'best',
#   'watergate',
#   'snitch',
#   'deep',
#   'throat',
#   'get',
#   'movie',
#   'treatment',
#   'suited',
#   'printed',
#   'page',
#   'big',
#   'screen'],
#  ['intelligent', 'espionage', 'thriller', 'present', 'u', 'moral', 'dilemma'],
#  ['logan',
#   'gamely',
#   'bat',
#   'away',
#   'genre',
#   'perceived',
#   'narrative',
#   'mold',
#   'fatigue',
#   'jettisoning',
#   'previously',
#   'de',
#   'clawed',
#   'rated',
#   'wolverine',
#   'favour',
#   'full',
#   'fat',
#   'crimson',
#   'soaked',
#   'final',
#   'outing',
#   'iconic',
#   'mutant'],
#  ['best',
#   'thing',
#   'hunger',
#   'game',
#   'mockingjay',
#   'part',
#   'unconcerned',
#   'expect',
#   'term',
#   'closure',
#   'happy',
#   'ending'],
#  ['whole', 'seems', 'meander', 'aimlessly', 'rarely', 'creating', 'chill'],
#  ['film', 'seems', 'le', 'problem', 'idea', 'story', 'could', 'dramatized'],
#  ['pulse',
#   'erudition',
#   'visual',
#   'kick',
#   'dulled',
#   'impact',
#   'time',
#   'sensitive',
#   'bottled',
#   'message',
#   'washed',
#   'ashore',
#   'year',
#   'late',
#   'practical',
#   'use'],
#  ['neither',
#   'original',
#   'packed',
#   'surprise',
#   'however',
#   'entertaining',
#   'thoroughly',
#   'likable'],
#  ['despite',
#   'mugging',
#   'macy',
#   'spark',
#   'genuine',
#   'turmoil',
#   'generated',
#   'ever',
#   'surprising',
#   'maguire',
#   'spontaneous',
#   'moment',
#   'whole',
#   'picture'],
#  ['smattering',
#   'effective',
#   'moment',
#   'creepy',
#   'cinematographic',
#   'look',
#   'sequel',
#   'redundancy',
#   'predecessor',
#   'pulseless',
#   'feint',
#   'tapping',
#   'human',
#   'emotion',
#   'leech',
#   'suspense',
#   'picture'],
#  ['intermittently', 'compelling', 'mostly', 'perfunctory'],
#  ['always',
#   'delightful',
#   'rose',
#   'byrne',
#   'gleeson',
#   'terrific',
#   'together',
#   'interaction',
#   'animated',
#   'creature',
#   'enough',
#   'lightly',
#   'recommend',
#   'film',
#   'despite',
#   'turning',
#   'peter',
#   'jerk',
#   'comeuppance'],
#  ['amid',
#   'episodic',
#   'muddle',
#   'din',
#   'done',
#   'yet',
#   'feel',
#   'assured',
#   'one',
#   'thing',
#   'one',
#   'guy'],
#  ['wondrous', 'film', 'kind', 'since', 'e', 'extra', 'terrestrial', 'touched'],
#  ['one', 'scariest', 'movie', 'stream'],
#  ['good',
#   'reason',
#   'see',
#   'new',
#   'film',
#   'scenery',
#   'generally',
#   'fine',
#   'acting'],
#  ['unfortunately',
#   'much',
#   'movie',
#   'plot',
#   'hinge',
#   'belief',
#   'costner',
#   'hopelessly',
#   'head',
#   'heel',
#   'love',
#   'russo',
#   'chemistry',
#   'together'],
#  ['michael',
#   'mann',
#   'foregoes',
#   'pastel',
#   'panache',
#   'original',
#   'colin',
#   'farrell',
#   'cat',
#   'johnson',
#   'result',
#   'bad',
#   'different'],
#  ['sprawling',
#   'wan',
#   'na',
#   'short',
#   'cut',
#   'tale',
#   'top',
#   'insufferably',
#   'unpleasant',
#   'make',
#   'even',
#   'infamous',
#   'american',
#   'psycho',
#   'seem',
#   'tame',
#   'comparison'],
#  ['even',
#   'look',
#   'past',
#   'horror',
#   'flick',
#   'hopelessly',
#   'flawed',
#   'theology',
#   'character',
#   'emotional',
#   'weight',
#   'constant',
#   'suspense',
#   'tiring',
#   'thrilling'],
#  ['take',
#   'minute',
#   'pirate',
#   'radio',
#   'run',
#   'steam',
#   'leaf',
#   'two',
#   'hour',
#   'aimless',
#   'goofing'],
#  ['typical',
#   'pic',
#   'adherence',
#   'rigid',
#   'genre',
#   'convention',
#   'first',
#   'victim',
#   'brazen',
#   'hotties',
#   'shown',
#   'drinking',
#   'dancing',
#   'wearing',
#   'revealing',
#   'attire',
#   'prior',
#   'death'],
#  ['tom', 'hank', 'born', 'play', 'sully'],
#  ['turn', 'trick', 'psychology', 'duplicitous', 'high', 'play'],
#  ['title',
#   'classic',
#   'example',
#   'overrated',
#   'movie',
#   'festival',
#   'little',
#   'impact',
#   'viewer',
#   'full',
#   'review',
#   'spanish'],
#  ['easy',
#   'fall',
#   'back',
#   'self',
#   'conscious',
#   'humor',
#   'author',
#   'keep',
#   'interrupting',
#   'story',
#   'remind',
#   'audience',
#   'dumb',
#   'material',
#   'point',
#   'telling',
#   'tale',
#   'first',
#   'place'],
#  ['movie',
#   'core',
#   'question',
#   'couple',
#   'face',
#   'much',
#   'one',
#   'identity',
#   'must',
#   'person',
#   'give',
#   'order',
#   'make',
#   'relationship',
#   'work',
#   'filmmaker',
#   'show',
#   'good',
#   'marketing',
#   'sense',
#   'balancing',
#   'romantic',
#   'element',
#   'sport'],
#  ['eastwood',
#   'display',
#   'futility',
#   'iraq',
#   'war',
#   'given',
#   'year',
#   'film',
#   'idea',
#   'image',
#   'startling',
#   'even',
#   'moving',
#   'message'],
#  ['film',
#   'encourages',
#   'u',
#   'look',
#   'beyond',
#   'surface',
#   'dealing',
#   'people',
#   'might',
#   'one',
#   'heart',
#   'warming',
#   'redemptive',
#   'movie',
#   'year'],
#  ['reitman',
#   'wilson',
#   'many',
#   'good',
#   'idea',
#   'men',
#   'woman',
#   'child',
#   'many',
#   'men',
#   'woman',
#   'child'],
#  ['opera',
#   'theater',
#   'director',
#   'william',
#   'oldroy',
#   'first',
#   'film',
#   'appear',
#   'dignity',
#   'best',
#   'year',
#   'list',
#   'also',
#   'perverse',
#   'accompaniment',
#   'contrast',
#   'piece',
#   'first',
#   'film',
#   'jordan',
#   'peele',
#   'directed',
#   'get',
#   'full',
#   'review',
#   'spanish'],
#  ['stewart',
#   'pattinson',
#   'convincing',
#   'chemistry',
#   'star',
#   'crossed',
#   'lover'],
#  ['close',
#   'give',
#   'intriguing',
#   'performance',
#   'technically',
#   'flawless',
#   'necessity',
#   'distant'],
#  ['feel',
#   'like',
#   'something',
#   'dali',
#   'would',
#   'dreamed',
#   'imbibing',
#   'bottle',
#   'absinthe',
#   'choking',
#   'ham',
#   'sandwich'],
#  ['take',
#   'encourages',
#   'audience',
#   'show',
#   'greater',
#   'appreciation',
#   'artistry',
#   'display',
#   'persistent',
#   'con',
#   'double',
#   'crossing',
#   'ultimately',
#   'prove',
#   'tiresome',
#   'distraction'],
#  ['ang',
#   'lee',
#   'film',
#   'show',
#   'even',
#   'modicum',
#   'originality',
#   'direction',
#   'real',
#   'personality',
#   'interesting',
#   'visual',
#   'flair'],
#  ['quip', 'filled', 'mean', 'spirited', 'slugfest'],
#  ['engaging',
#   'thriller',
#   'thoroughly',
#   'satisfy',
#   'genre',
#   'fan',
#   'time',
#   'year',
#   'choice',
#   'essentially',
#   'bad',
#   'worse'],
#  ['one', 'emotionally', 'powerful', 'film', 'year'],
#  ['interesting',
#   'yet',
#   'erratic',
#   'true',
#   'life',
#   'story',
#   'could',
#   'much',
#   'better'],
#  ['revelation', 'could', 'live', 'buildup', 'one'],
#  ['sure', 'wow', 'critic', 'movie', 'mass'],
#  ['best',
#   'moment',
#   'occur',
#   'fantasy',
#   'dream',
#   'sequence',
#   'bush',
#   'face',
#   'darkest',
#   'fear',
#   'stone',
#   'get',
#   'across',
#   'secret',
#   'theory'],
#  ['bayona',
#   'try',
#   'best',
#   'make',
#   'movie',
#   'feel',
#   'different',
#   'predecessor',
#   'come',
#   'short',
#   'full',
#   'review',
#   'spanish'],
#  ['problem',
#   'screen',
#   'adaptation',
#   'young',
#   'adult',
#   'novel',
#   'spend',
#   'much',
#   'time',
#   'struggling',
#   'explain',
#   'world',
#   'creating',
#   'forget',
#   'part',
#   'story',
#   'people',
#   'want',
#   'see',
#   'figure',
#   'people',
#   'kid'],
#  ['like', 'cheek', 'film', 'good', 'new', 'one', 'long', 'stretch', 'bad'],
#  ['black', 'heart', 'right', 'place'],
#  ['magnolia',
#   'make',
#   'three',
#   'three',
#   'writer',
#   'director',
#   'paul',
#   'thomas',
#   'anderson'],
#  ['john',
#   'carter',
#   'arriving',
#   'late',
#   'party',
#   'george',
#   'lucas',
#   'already',
#   'pillaged',
#   'source',
#   'material',
#   'squeezed',
#   'every',
#   'dollar',
#   'worth',
#   'stanton',
#   'created',
#   'sci',
#   'fi',
#   'adventure',
#   'feel',
#   'old',
#   'hat',
#   'sub',
#   'par'],
#  ['exhibitionist',
#   'ferrell',
#   'finding',
#   'another',
#   'excuse',
#   'expose',
#   'movie',
#   'leaving',
#   'danger',
#   'going',
#   'cinematic',
#   'history',
#   'man',
#   'nude',
#   'much'],
#  ['could', 'use', 'little', 'le', 'star', 'power', 'little', 'ennui'],
#  ['christmas', 'film', 'funnier'],
#  ['documentary',
#   'filmmaker',
#   'kirby',
#   'dick',
#   'take',
#   'incendiary',
#   'topic',
#   'rape',
#   'campus',
#   'case',
#   'mount',
#   'institutional',
#   'rep',
#   'succeed',
#   'best',
#   'playing',
#   'dumb',
#   'hunting',
#   'ground',
#   'becomes',
#   'energizing',
#   'call',
#   'action'],
#  ['enchant',
#   'kid',
#   'single',
#   'digit',
#   'age',
#   'adult',
#   'find',
#   'said',
#   'kid',
#   'also',
#   'great',
#   'way',
#   'introducing',
#   'child',
#   'joy',
#   'silent',
#   'film'],
#  ['battle',
#   'scene',
#   'spectacular',
#   'great',
#   'explosion',
#   'screen',
#   'time',
#   'taken',
#   'contrived',
#   'schmaltzy',
#   'script',
#   'little',
#   'emotional',
#   'punch'],
#  ['awkward', 'unsatisfying'],
#  ['contrived',
#   'fantasy',
#   'hollywood',
#   'could',
#   'harrelson',
#   'get',
#   'theron',
#   'nemesis',
#   'recant',
#   'inadmissably',
#   'irrelevant',
#   'tale',
#   'stand',
#   'meager',
#   'questioning'],
#  ['genuinely', 'funny', 'moment', 'whole', 'repetitive', 'stale'],
#  ['undoubtedly',
#   'perfect',
#   'example',
#   'everything',
#   'wrong',
#   'contemporary',
#   'action',
#   'flick',
#   'although',
#   'movie',
#   'quite',
#   'bad',
#   'made'],
#  ['hood', 'hook', 'dancing', 'debutante', 'across', 'track', 'romance'],
#  ['pallid',
#   'formulaic',
#   'teen',
#   'romance',
#   'might',
#   'benefited',
#   'little',
#   'snark'],
#  ['good',
#   'sterling',
#   'one',
#   'liner',
#   'generous',
#   'handful',
#   'sparkling',
#   'scene',
#   'strong',
#   'peppery',
#   'start',
#   'movie',
#   'collapse',
#   'bland',
#   'mush',
#   'want',
#   'anything',
#   'interesting',
#   'say'],
#  ['topical',
#   'comedy',
#   'today',
#   'feel',
#   'like',
#   'something',
#   'day',
#   'old',
#   'bin',
#   'however',
#   'disaster',
#   'much',
#   'delayed',
#   'release',
#   'might',
#   'indicate'],
#  ['harm', 'done', 'really', 'nothing', 'lasting', 'value', 'either'],
#  ['film',
#   'might',
#   'funny',
#   'poorly',
#   'executed',
#   'fixated',
#   'bodily',
#   'function'],
#  ['nothing',
#   'detracts',
#   'quality',
#   'ensemble',
#   'performance',
#   'actor',
#   'capably',
#   'express',
#   'inner',
#   'feeling',
#   'happiness',
#   'company',
#   'fearfulness',
#   'person',
#   'colour',
#   'america'],
#  ['root',
#   'family',
#   'assault',
#   'murderous',
#   'hooligan',
#   'hooligan',
#   'behave',
#   'like',
#   'idiot'],
#  ['exceptionally', 'incredibly', 'lazy', 'piece', 'work'],
#  ['surprisingly',
#   'thematically',
#   'rich',
#   'third',
#   'installment',
#   'horror',
#   'franchise'],
#  ['award',
#   'season',
#   'swirling',
#   'around',
#   'u',
#   'mr',
#   'langella',
#   'mr',
#   'sheen',
#   'hard',
#   'overlook',
#   'prize',
#   'dispensed'],
#  ['workmanlike',
#   'entry',
#   'brings',
#   'moore',
#   'long',
#   'increasingly',
#   'tired',
#   'tenure',
#   'close'],
#  ['looking', 'age', 'crowd', 'pleaser', 'may', 'best', 'bet'],
#  ['cedric',
#   'entertainer',
#   'give',
#   'might',
#   'worst',
#   'performance',
#   'year',
#   'forgetting',
#   'walk',
#   'remember',
#   'mandy',
#   'moore'],
#  ['musical',
#   'moment',
#   'punctuated',
#   'awkward',
#   'stilted',
#   'dialog',
#   'completely',
#   'kill',
#   'movie',
#   'momentum'],
#  ['angelou', 'life', 'touched', 'miss'],
#  ['meandering', 'maudlin', 'drearily', 'predictable'],
#  ['dramatic',
#   'theme',
#   'echo',
#   'great',
#   'crime',
#   'movie',
#   'seventy',
#   'modern',
#   'flash',
#   'muscle',
#   'ultimately',
#   'win',
#   'pacey',
#   'yet',
#   'le',
#   'satisfying',
#   'action',
#   'thriller'],
#  ['whether',
#   'world',
#   'need',
#   'another',
#   'tarzan',
#   'kind',
#   'fairly',
#   'clear',
#   'need',
#   'one'],
#  ['get', 'march', 'massacre', 'rooted', 'seat'],
#  ['movie', 'stifling', 'familiarity', 'prevents', 'making', 'much', 'impact'],
#  ['woody',
#   'harrelson',
#   'give',
#   'impressionistic',
#   'performance',
#   'look',
#   'much',
#   'like',
#   'lbj',
#   'even',
#   'make',
#   'bring',
#   'voice',
#   'low',
#   'register',
#   'understands',
#   'coyote',
#   'cunning',
#   'man'],
#  ['film', 'never', 'really', 'explains', 'g', 'came', 'going'],
#  ['fleeting',
#   'moment',
#   'well',
#   'directed',
#   'tension',
#   'first',
#   'yarn',
#   'nightwatchman',
#   'make',
#   'copy',
#   'cat',
#   'contrivance',
#   'rest',
#   'film'],
#  ['deliberate',
#   'demanding',
#   'character',
#   'driven',
#   'michael',
#   'clayton',
#   'fly',
#   'face',
#   'sell',
#   'multiplex'],
#  ['breadwinner',
#   'thrillingly',
#   'alive',
#   'delicacy',
#   'artistry',
#   'wit',
#   'human',
#   'touch'],
#  ['caesar', 'main', 'ape', 'reason', 'see', 'daft', 'breathless', 'picture'],
#  ['one',
#   'thing',
#   'world',
#   'need',
#   'sequel',
#   'daredevil',
#   'luckily',
#   'got',
#   'unfortunately',
#   'arrived',
#   'place',
#   'much',
#   'better'],
#  ['clooney',
#   'go',
#   'instinct',
#   'script',
#   'make',
#   'choice',
#   'play',
#   'majority',
#   'movie',
#   'straight',
#   'moment',
#   'comedy',
#   'come',
#   'feel',
#   'completely',
#   'wrong',
#   'tone',
#   'deaf'],
#  ['thoroughly',
#   'charming',
#   'story',
#   'enough',
#   'magic',
#   'slapstick',
#   'please',
#   'youngster',
#   'enough',
#   'heart',
#   'make',
#   'mom',
#   'dad',
#   'happy'],
#  ['j',
#   'blakeson',
#   'keep',
#   'suspense',
#   'level',
#   'high',
#   'first',
#   'hour',
#   'indulges',
#   'plot',
#   'twist',
#   'strain',
#   'credibility'],
#  ['demonstrating',
#   'limit',
#   'clever',
#   'genre',
#   'movie',
#   'art',
#   'house',
#   'chiller',
#   'silent',
#   'house',
#   'let',
#   'tenseness',
#   'first',
#   'act',
#   'trickle',
#   'away'],
#  ['fan',
#   'original',
#   'film',
#   'find',
#   'much',
#   'enjoy',
#   'though',
#   'really',
#   'would',
#   'morally',
#   'indefensible',
#   'encourage'],
#  ['life',
#   'party',
#   'avoids',
#   'easy',
#   'girl',
#   'versus',
#   'girl',
#   'conflict',
#   'maya',
#   'rudolph',
#   'deanna',
#   'adult',
#   'best',
#   'friend',
#   'christine',
#   'bff',
#   'need',
#   'life'],
#  ['nice', 'see', 'representation', 'presented', 'normal'],
#  ['assembles',
#   'part',
#   'assured',
#   'astute',
#   'way',
#   'changing',
#   'even',
#   'one',
#   'element',
#   'seems',
#   'unthinkable'],
#  ['spunky',
#   'determination',
#   'spirit',
#   'melfi',
#   'film',
#   'manages',
#   'calculate',
#   'path',
#   'winning',
#   'formula',
#   'succeeds'],
#  ['truly', 'classic', 'moment'],
#  ['zombie',
#   'may',
#   'able',
#   'match',
#   'stalk',
#   'n',
#   'menace',
#   'carpenter',
#   'steadicam',
#   'original',
#   'big',
#   'z',
#   'knife',
#   'hit',
#   'right',
#   'groove',
#   'cut',
#   'dark',
#   'heart',
#   'myers',
#   'legend'],
#  ['almost',
#   'unmitigated',
#   'disaster',
#   'major',
#   'studio',
#   'production',
#   'major',
#   'star',
#   'lead',
#   'oscar',
#   'winning',
#   'halle',
#   'berry',
#   'come',
#   'across',
#   'like',
#   'direct',
#   'video',
#   'production',
#   'complete',
#   'ultra',
#   'lame',
#   'computer',
#   'generated',
#   'effect',
#   'clueless',
#   'direction'],
#  ['michael',
#   'moore',
#   'trumpland',
#   'sway',
#   'single',
#   'voter',
#   'may',
#   'even',
#   'amuse',
#   'moore',
#   'core',
#   'audience',
#   'disillusioned',
#   'liberal'],
#  ['fluctuates', 'sublime', 'tedious', 'throughout'],
#  ['movie', 'feel', 'deeply', 'personal', 'little', 'confused'],
#  ['even',
#   'film',
#   'one',
#   'point',
#   'us',
#   'karma',
#   'police',
#   'earnestly',
#   'sarcastically',
#   'fully',
#   'atone',
#   'time',
#   'simply',
#   'scream',
#   'generic',
#   'nihilism'],
#  ['film',
#   'taut',
#   'insightful',
#   'arc',
#   'reminder',
#   'lost',
#   'power',
#   'restraint'],
#  ['pacific',
#   'rim',
#   'uprising',
#   'mindless',
#   'delight',
#   'delight',
#   'audience',
#   'member',
#   'love',
#   'kind',
#   'junk',
#   'food',
#   'cinema',
#   'full',
#   'content',
#   'review',
#   'parent',
#   'violence',
#   'profanity',
#   'etc',
#   'also',
#   'available'],
#  ['dip',
#   'style',
#   'excitement',
#   'vibrancy',
#   'sport',
#   'recreates',
#   'atmosphere',
#   'real',
#   'sense',
#   'period',
#   'outside',
#   'crash',
#   'barrier'],
#  ['bother',
#   'take',
#   'note',
#   'subplots',
#   'go',
#   'nowhere',
#   'character',
#   'many',
#   'played',
#   'well',
#   'known',
#   'actor',
#   'barely',
#   'get',
#   'screen',
#   'time'],
#  ['even',
#   'talented',
#   'ensemble',
#   'love',
#   'cooper',
#   'convoluted',
#   'narrative',
#   'overreliance',
#   'christmas',
#   'clich',
#   'keep',
#   'sparking',
#   'real',
#   'holiday',
#   'magic'],
#  ['king',
#   'visual',
#   'essay',
#   'proposes',
#   'thesis',
#   'build',
#   'convincing',
#   'argument',
#   'bouncing',
#   'presley',
#   'life',
#   'state',
#   'nation'],
#  ['passable', 'pointless', 'remake', 'slick', 'empty'],
#  ['lovely',
#   'filmmaking',
#   'opening',
#   'sequence',
#   'handmade',
#   'barbie',
#   'move',
#   'stage',
#   'stage',
#   'hair',
#   'weaving',
#   'lip',
#   'painting',
#   'gorgeous'],
#  ['minnie',
#   'driver',
#   'give',
#   'jane',
#   'throaty',
#   'teasing',
#   'allure',
#   'suggests',
#   'night',
#   'jungle',
#   'disney',
#   'dull',
#   'man'],
#  ['mummy',
#   'series',
#   'dead',
#   'long',
#   'time',
#   'like',
#   'mummy',
#   'depicts',
#   'stay',
#   'buried'],
#  ['could',
#   'fun',
#   'kid',
#   'film',
#   'chicken',
#   'little',
#   'turn',
#   'exercise',
#   'old',
#   'school',
#   'disney',
#   'paint',
#   'number',
#   'storytelling'],
#  ['bava',
#   'let',
#   'action',
#   'play',
#   'loose',
#   'big',
#   'sly',
#   'subversion',
#   'lurks',
#   'beneath',
#   'camp',
#   'exterior'],
#  ['though',
#   'suffers',
#   'stumble',
#   'along',
#   'way',
#   'definitely',
#   'chicken',
#   'end',
#   'much',
#   'running',
#   'time',
#   'deliciously',
#   'deadpan',
#   'satire',
#   'cult',
#   'grow',
#   'around',
#   'dead',
#   'celebrity'],
#  ['whole',
#   'lot',
#   'already',
#   'eaten',
#   'digested',
#   'time',
#   'far',
#   'interesting',
#   'look',
#   'forward',
#   'elvis',
#   'really',
#   'dead',
#   'time',
#   'let',
#   'go'],
#  ['first',
#   'half',
#   'week',
#   'later',
#   'highly',
#   'enjoyable',
#   'assuming',
#   'find',
#   'thing',
#   'like',
#   'cowardice',
#   'official',
#   'incompetence',
#   'nihilistic',
#   'vision',
#   'future',
#   'entertaining'],
#  ['cuaron',
#   'team',
#   'crafted',
#   'masterpiece',
#   'much',
#   'seems',
#   'piece',
#   'come',
#   'together',
#   'form',
#   'one',
#   'unforgettable',
#   'movie',
#   'going',
#   'experience',
#   'recent',
#   'memory'],
#  ['hold',
#   'candle',
#   'spike',
#   'jonze',
#   'insight',
#   'man',
#   'relationship',
#   'artificial',
#   'intelligence',
#   'stunning',
#   'location',
#   'brilliant',
#   'design',
#   'seamless',
#   'visual',
#   'effect',
#   'story',
#   'begs',
#   'question'],
#  ['movie',
#   'think',
#   'past',
#   'year',
#   'doubt',
#   'conceived',
#   'produced',
#   'sole',
#   'purpose',
#   'winning',
#   'oscar',
#   'exists',
#   'compliment'],
#  ['usual',
#   'trope',
#   'iary',
#   'stunt',
#   'oriental',
#   'wisdom',
#   'redeemed',
#   'stellar',
#   'work',
#   'main',
#   'role'],
#  ['young', 'snarky', 'smart', 'surprising', 'right', 'final', 'shot'],
#  ['first', 'partially', 'succeed', 'repeat', 'formula'],
#  ['left',
#   'theatre',
#   'feeling',
#   'spent',
#   'satisfying',
#   'evening',
#   'movie',
#   'retrospect',
#   'wish',
#   'screenwriter',
#   'tweaked',
#   'story',
#   'sophistication',
#   'much',
#   'technical',
#   'effect'],
#  ['married',
#   'life',
#   'enough',
#   'plot',
#   'twist',
#   'moment',
#   'high',
#   'tension',
#   'keep',
#   'viewer',
#   'engaged',
#   'main',
#   'point',
#   'interest',
#   'character'],
#  ['despite',
#   'movie',
#   'gripping',
#   'performance',
#   'verisimilitude',
#   'many',
#   'element',
#   'simply',
#   'believe',
#   'story'],
#  ['hemmed',
#   'theatrically',
#   'bound',
#   'staging',
#   'pontypool',
#   'overly',
#   'inflated',
#   'zombie',
#   'flick',
#   'make',
#   'overture',
#   'weighty',
#   'theme',
#   'social',
#   'consciousness',
#   'screenwriter',
#   'ill',
#   'prepared',
#   'fulfill'],
#  ['stylish',
#   'line',
#   'creamy',
#   'production',
#   'value',
#   'human',
#   'capital',
#   'combine',
#   'luxurious',
#   'look',
#   'classic',
#   'wish',
#   'fulfillment',
#   'fantasy',
#   'stinging',
#   'critique',
#   'capitalism',
#   'excess',
#   'psychic',
#   'cost'],
#  ['maybe',
#   'next',
#   'time',
#   'director',
#   'matthew',
#   'vaughn',
#   'could',
#   'leave',
#   'kitchen',
#   'sink',
#   'home'],
#  ['laid',
#   'back',
#   'colorful',
#   'groovy',
#   'glimpse',
#   'magic',
#   'woodstock',
#   'viewed',
#   'life',
#   'tight',
#   'young',
#   'man',
#   'great',
#   'caretaker',
#   'unable',
#   'treat',
#   'care',
#   'support',
#   'give',
#   'others'],
#  ['end', 'saddest', 'thing', 'idlewild', 'piece', 'present', 'good', 'film'],
#  ['sure',
#   'film',
#   'share',
#   'scattered',
#   'clich',
#   'befall',
#   'jumpy',
#   'road',
#   'flick',
#   'still',
#   'one',
#   'deny',
#   'reflective',
#   'raucous',
#   'vibe',
#   'emanate',
#   'rag',
#   'tag',
#   'pulpy',
# ...
#   'complete',
#   'performance',
#   'sally',
#   'hawkins'],
#  ['surely',
#   'finest',
#   'film',
#   'made',
#   'heavily',
#   'recycled',
#   'concept',
#   'endeavor',
#   'fine',
#   'basic',
#   'provocation',
#   'helplessness',
#   'making',
#   'effort',
#   'type',
#   'movie',
#   'usually',
#   'receives'],
#  ['clumsy',
#   'implausible',
#   'terrorist',
#   'action',
#   'drama',
#   'olympus',
#   'fallen',
#   'fall',
#   'period',
#   'prime',
#   'movie',
#   'going',
#   'season',
#   'show'],
#  ['talk',
#   'girl',
#   'party',
#   'overshadowed',
#   'need',
#   'eccentric',
#   'hard',
#   'take',
#   'seriously',
#   'even',
#   'trying',
#   'take',
#   'seriously'],
#  ['tender',
#   'touching',
#   'drama',
#   'based',
#   'true',
#   'story',
#   'troubled',
#   'african',
#   'american',
#   'quest',
#   'come',
#   'term',
#   'origin',
#   'reveals',
#   'yearning',
#   'heart',
#   'acceptance',
#   'within',
#   'family',
#   'circle'],
#  ['happens',
#   'really',
#   'talented',
#   'director',
#   'sometimes',
#   'step',
#   'batter',
#   'box',
#   'take',
#   'gigantic',
#   'swing',
#   'whiff'],
#  ['watermelon',
#   'woman',
#   'awkward',
#   'clunky',
#   'shoestring',
#   'budget',
#   'sometimes',
#   'show',
#   'also',
#   'fresh',
#   'frequently',
#   'funny'],
#  ['every',
#   'generation',
#   'get',
#   'ripper',
#   'best',
#   'fulfills',
#   'fantasy',
#   'fatten',
#   'vast',
#   'conspiracy'],
#  ['vivid',
#   'moving',
#   'breathlessly',
#   'exciting',
#   'enthralling',
#   'mingling',
#   'fable',
#   'travelogue',
#   'social',
#   'commentary',
#   'see',
#   'danny',
#   'boyle',
#   'top',
#   'game',
#   'phone',
#   'friend',
#   'tell',
#   'miss'],
#  ['franchise',
#   'never',
#   'dazzled',
#   'brilliance',
#   'certainly',
#   'baffle',
#   'something',
#   'else',
#   'mostly',
#   'video',
#   'game',
#   'style',
#   'violence',
#   'occasionally',
#   'pausing',
#   'necessary',
#   'exposition',
#   'home',
#   'would',
#   'time',
#   'rest',
#   'thumb'],
#  ['title',
#   'character',
#   'barney',
#   'version',
#   'left',
#   'wishing',
#   'someone',
#   'would',
#   'give',
#   'unrelenting',
#   'boor',
#   'boa',
#   'constrictor',
#   'necktie'],
#  ['flawlessly',
#   'heartbreakingly',
#   'capture',
#   'joy',
#   'fallibility',
#   'transcendence',
#   'one',
#   'ever',
#   'fleeting',
#   'existence',
#   'roger',
#   'ebert',
#   'may',
#   'longer',
#   'impact',
#   'legacy',
#   'endure'],
#  ['jack',
#   'reacher',
#   'never',
#   'go',
#   'back',
#   'feel',
#   'quite',
#   'exciting',
#   'perhaps',
#   'inevitable',
#   'letdown',
#   'come',
#   'sequel',
#   'perhaps',
#   'good'],
#  ['marketed',
#   'horror',
#   'thriller',
#   'sharply',
#   'well',
#   'made',
#   'film',
#   'actually',
#   'bleak',
#   'drama',
#   'strong',
#   'message',
#   'bullying'],
#  ['much',
#   'appreciated',
#   'performance',
#   'terrifically',
#   'talented',
#   'cast',
#   'much',
#   'liked',
#   'dreamgirls',
#   'love',
#   'maybe',
#   'little',
#   'slick',
#   'top',
#   'good'],
#  ['enjoyed',
#   'jumanji',
#   'robin',
#   'williams',
#   'film',
#   'board',
#   'game',
#   'wild',
#   'animal',
#   'come',
#   'life',
#   'rest',
#   'sentence',
#   'read',
#   'dullard',
#   'slapped',
#   'repeatedly'],
#  ['f',
#   'scott',
#   'fitzgerald',
#   'remarked',
#   'rich',
#   'different',
#   'might',
#   'thinking',
#   'someone',
#   'like',
#   'moody',
#   'billionaire',
#   'fierce',
#   'people'],
#  ['goldsman',
#   'directorial',
#   'debut',
#   'decorated',
#   'list',
#   'cast',
#   'watch',
#   'smith',
#   'must',
#   'one',
#   'assume',
#   'family',
#   'held',
#   'hostage',
#   'somewhere',
#   'even',
#   'colin',
#   'farrell',
#   'standard',
#   'goldsman',
#   'tale',
#   'mawkish',
#   'stinker'],
#  ['may',
#   'well',
#   'satisfy',
#   'witching',
#   'hour',
#   'mass',
#   'get',
#   'anyone',
#   'skin',
#   'dream'],
#  ['agreeably', 'shallow', 'comedy'],
#  ['brisk', 'engrossing', 'intelligent', 'thriller'],
#  ['made',
#   'film',
#   'obtuse',
#   'alienating',
#   'never',
#   'made',
#   'one',
#   'self',
#   'defeatingly',
#   'dull',
#   'keep',
#   'waiting',
#   'movie',
#   'start'],
#  ['tedious', 'affair', 'tedious', 'affair'],
#  ['eastwood',
#   'newcomer',
#   'director',
#   'chair',
#   'failure',
#   'mind',
#   'detail',
#   'downgrade',
#   'american',
#   'sniper',
#   'potentially',
#   'great',
#   'film',
#   'one',
#   'quite',
#   'good',
#   'enough'],
#  ['biased',
#   'showy',
#   'hero',
#   'worship',
#   'rightfully',
#   'absent',
#   'solid',
#   'biography',
#   'slice'],
#  ['like',
#   'wepner',
#   'favorite',
#   'movie',
#   'chuck',
#   'requiem',
#   'heavyweight',
#   'palooka',
#   'nothing',
#   'left',
#   'pride'],
#  ['american',
#   'south',
#   'peculiar',
#   'institution',
#   'seems',
#   'become',
#   'fit',
#   'topic',
#   'narrative',
#   'cinema',
#   'took',
#   'century'],
#  ['enjoyable',
#   'consistently',
#   'beautiful',
#   'fairly',
#   'conventional',
#   'occasionally',
#   'surprising',
#   'ultimately',
#   'disappointing'],
#  ['instead',
#   'birthing',
#   'new',
#   'method',
#   'distribution',
#   'netflix',
#   'demonstrated',
#   'high',
#   'profile',
#   'dumping',
#   'garbage',
#   'product'],
#  ['light',
#   'humor',
#   'help',
#   'make',
#   'palatable',
#   'violent',
#   'scene',
#   'film',
#   'also',
#   'read',
#   'full',
#   'content',
#   'review',
#   'parent'],
#  ['real', 'tension', 'film', 'seem', 'formulaic', 'full', 'review', 'spanish'],
#  ['strong',
#   'predecessor',
#   'sicario',
#   'day',
#   'soldado',
#   'still',
#   'feature',
#   'great',
#   'piece',
#   'leave',
#   'edge',
#   'seat'],
#  ['annoying',
#   'hopelessly',
#   'silly',
#   'taken',
#   'seriously',
#   'either',
#   'parody',
#   'satire',
#   'command',
#   'involvement',
#   'whatsoever',
#   'either',
#   'character',
#   'story'],
#  ['detour',
#   'exactly',
#   'remake',
#   'film',
#   'noir',
#   'name',
#   'christopher',
#   'smith',
#   'teen',
#   'neo',
#   'noir',
#   'think',
#   'brick',
#   'vega',
#   'nothing',
#   'stylish',
#   'often',
#   'gripping',
#   'homage'],
#  ['writing',
#   'direction',
#   'pull',
#   'punch',
#   'opting',
#   'cool',
#   'tm',
#   'ethos',
#   'hazy',
#   'glow',
#   'tribute',
#   'instead',
#   'messy',
#   'reality',
#   'greene',
#   'reveled',
#   'lancing'],
#  ['mulligan',
#   'brilliant',
#   'chilly',
#   'sci',
#   'fi',
#   'love',
#   'story',
#   'get',
#   'mired',
#   'tedium',
#   'frustrates',
#   'lot',
#   'unanswered',
#   'question',
#   'probably',
#   'design'],
#  ['take',
#   'clever',
#   'schoolboy',
#   'make',
#   'movie',
#   'elaborately',
#   'empty',
#   'guy',
#   'ritchie',
#   'snatch'],
#  ['occasion',
#   'information',
#   'sustained',
#   'introspection',
#   'feel',
#   'necessary',
#   'also',
#   'time',
#   'image',
#   'speak'],
#  ['intelligently',
#   'inspiring',
#   'faith',
#   'based',
#   'drama',
#   'link',
#   'fate',
#   'family',
#   'rwanda',
#   'nashville'],
#  ['vital',
#   'part',
#   'kemp',
#   'extension',
#   'thompson',
#   'development',
#   'rum',
#   'diary',
#   'discovery',
#   'voice',
#   'concept',
#   'robinson',
#   'seems',
#   'disinterested'],
#  ['clever', 'funny', 'animated', 'romp', 'kid', 'adult', 'enjoy'],
#  ['hand',
#   'coen',
#   'brother',
#   'even',
#   'cinematic',
#   'failure',
#   'pretty',
#   'interesting'],
#  ['enjoyable',
#   'previous',
#   'instalment',
#   'mind',
#   'best',
#   'series',
#   'director',
#   'bill',
#   'condon',
#   'film',
#   'step',
#   'backwards',
#   'quality'],
#  ['scotland',
#   'pa',
#   'strangely',
#   'drab',
#   'romp',
#   'studio',
#   'pizazz',
#   'might',
#   'helped'],
#  ['fair',
#   'embarrassed',
#   'onscreen',
#   'spirit',
#   'movie',
#   'dialogue',
#   'would',
#   'tax',
#   'thespian',
#   'talent',
#   'anyone'],
#  ['merely', 'unnecessary', 'mostly', 'unsuccessful', 'footnote'],
#  ['something',
#   'jarringly',
#   'misanthropic',
#   'screenwriter',
#   'justin',
#   'haythe',
#   'ted',
#   'elliott',
#   'terry',
#   'rossio',
#   'rendition',
#   'iconic',
#   'hero'],
#  ['three', 'hanky', 'weepy', 'nearly', 'grating'],
#  ['easy',
#   'enough',
#   'see',
#   'story',
#   'could',
#   'hit',
#   'cinematic',
#   'pay',
#   'dirt',
#   'glibness',
#   'telling',
#   'make',
#   'strangely',
#   'uninvolving'],
#  ['made',
#   'unprecedentedly',
#   'movie',
#   'almost',
#   'entirely',
#   'literal',
#   'even',
#   'fantastical',
#   'liberty',
#   'made',
#   'possible',
#   'closed',
#   'world',
#   'reygadas',
#   'found',
#   'knock',
#   'still',
#   'skeptical',
#   'puzzled',
#   'behind'],
#  ['bj',
#   'mcdonnell',
#   'hatchet',
#   'trilogy',
#   'ender',
#   'compare',
#   'well',
#   'adam',
#   'green',
#   'hatchet',
#   'ii',
#   'still',
#   'plenty',
#   'slasher',
#   'fun',
#   'keep',
#   'hardcore',
#   'fan',
#   'watching',
#   'victor',
#   'crowley',
#   'last',
#   'hurrah'],
#  ['exceedingly',
#   'well',
#   'directed',
#   'cleverly',
#   'filmed',
#   'edited',
#   'tension',
#   'filled',
#   'affair',
#   'also',
#   'wholly',
#   'preposterous',
#   'muddled',
#   'paranoid',
#   'view',
#   'inner',
#   'city',
#   'nightmare',
#   'slightest',
#   'misstep',
#   'sure',
#   'fateful',
#   'result'],
#  ['start',
#   'interesting',
#   'exploration',
#   'identity',
#   'soon',
#   'give',
#   'way',
#   'uninspired',
#   'generic',
#   'action',
#   'flick',
#   'feared',
#   'always'],
#  ['behold', 'friend', 'superior', 'sequel'],
#  ['shapeless',
#   'unplotted',
#   'mangan',
#   'ruffled',
#   'rueful',
#   'affability',
#   'hail',
#   'sitcom',
#   'land'],
#  ['found',
#   'curling',
#   'paralysing',
#   'cringe',
#   'body',
#   'rolled',
#   'cinema',
#   'afterwards',
#   'like',
#   'dented',
#   'bicycle',
#   'wheel'],
#  ['wretched', 'dinge', 'almost', 'drecky', 'write', 'go', 'nothing'],
#  ['binoche',
#   'usual',
#   'give',
#   'communicating',
#   'character',
#   'complexity',
#   'believable',
#   'anguish',
#   'rather',
#   'thin',
#   'routine',
#   'material',
#   'never',
#   'quite',
#   'deserve'],
#  ['full', 'review', 'movie', 'mass'],
#  ['crisp',
#   'supporting',
#   'turn',
#   'john',
#   'turturro',
#   'hostage',
#   'negotiator',
#   'james',
#   'gandolfini',
#   'mayor',
#   'combine',
#   'plenty',
#   'vehicular',
#   'mayhem',
#   'make',
#   'superior',
#   'diversion'],
#  ['sometimes',
#   'star',
#   'smart',
#   'script',
#   'outshine',
#   'formulaic',
#   'framework'],
#  ['leon',
#   'grungy',
#   'r',
#   'sum',
#   'indie',
#   'modest',
#   'deal',
#   'sweet',
#   'mumblecore',
#   'style',
#   'ending',
#   'glow',
#   'unmistakable',
#   'star',
#   'power'],
#  ['movie',
#   'ultimately',
#   'long',
#   'name',
#   'player',
#   'traded',
#   'name',
#   'player',
#   'detailed',
#   'casual',
#   'viewer'],
#  ['refreshing',
#   'part',
#   'atl',
#   'kid',
#   'good',
#   'kid',
#   'unfortunately',
#   'good',
#   'kid',
#   'bad',
#   'movie'],
#  ['lovelace',
#   'becomes',
#   'distracted',
#   'industry',
#   'politics',
#   'cultural',
#   'context',
#   'film',
#   'release',
#   'provide',
#   'snapshot',
#   'life',
#   'either',
#   'stepped',
#   'front',
#   'camera'],
#  ['another',
#   'home',
#   'run',
#   'pixar',
#   'perfect',
#   'conclusion',
#   'perfect',
#   'movie',
#   'trilogy'],
#  ['gift', 'documentary'],
#  ['find', 'island', 'three', 'word', 'advice', 'vote'],
#  ['awkward',
#   'love',
#   'triangle',
#   'go',
#   'second',
#   'film',
#   'chance',
#   'robert',
#   'downey',
#   'jr',
#   'discovers',
#   'past',
#   'life',
#   'girlfriend',
#   'father',
#   'gross'],
#  ['nothing', 'seen', 'done', 'better'],
#  ['nakamura',
#   'us',
#   'watercolor',
#   'effect',
#   'elongated',
#   'human',
#   'figure',
#   'split',
#   'screen',
#   'capture',
#   'look',
#   'asumiko',
#   'nakamura',
#   'original',
#   'manga'],
#  ['filmmaker',
#   'focused',
#   'time',
#   'energy',
#   'fun',
#   'ditsy',
#   'bombshell',
#   'stereotype',
#   'faris',
#   'obviously',
#   'blast',
#   'portraying',
#   'left',
#   'way',
#   'without',
#   'unnecessary',
#   'character',
#   'growth',
#   'could'],
#  ['result',
#   'deep',
#   'impact',
#   'seems',
#   'mildly',
#   'engaging',
#   'well',
#   'rather',
#   'shallow'],
#  ['sturdy',
#   'uneven',
#   'film',
#   'leave',
#   'audience',
#   'disillusioned',
#   'perhaps',
#   'bit',
#   'horrified',
#   'truth',
#   'justice',
#   'contends',
#   'real',
#   'american',
#   'way'],
#  ['roos', 'find', 'element', 'truth', 'frustratingly'],
#  ['formulaic',
#   'word',
#   'go',
#   'many',
#   'trite',
#   'overused',
#   'device',
#   'could',
#   'serve',
#   'primer',
#   'thing',
#   'avoid',
#   'making',
#   'original',
#   'movie'],
#  ['close',
#   'solid',
#   'espionage',
#   'thriller',
#   'misfortune',
#   'released',
#   'decade',
#   'late'],
#  ['despite',
#   'cribbing',
#   'baseball',
#   'film',
#   'standard',
#   'issue',
#   'sport',
#   'fare',
#   'still',
#   'seems',
#   'intent',
#   'grafting',
#   'unnecessary',
#   'pile',
#   'story',
#   'top'],
#  ['woody',
#   'allen',
#   'beguiling',
#   'bedazzling',
#   'new',
#   'comedy',
#   'nostalgia',
#   'used',
#   'smarter',
#   'sweeter',
#   'fizzier',
#   'ever',
#   'much',
#   'funnier'],
#  ['visuals',
#   'feel',
#   'realistic',
#   'enough',
#   'engage',
#   'overall',
#   'insurgent',
#   'let',
#   'unless',
#   'hard',
#   'core',
#   'fan',
#   'novel',
#   'upon',
#   'based',
#   'wait',
#   'cable'],
#  ['melodramatic',
#   'outset',
#   'grace',
#   'monaco',
#   'play',
#   'like',
#   'sob',
#   'stricken',
#   'soapie',
#   'former',
#   'hollywood',
#   'star',
#   'acting',
#   'career',
#   'relationship',
#   'reality',
#   'treated',
#   'breathless',
#   'unbelievable',
#   'manner'],
#  ['manhunt',
#   'dense',
#   'information',
#   'revelation',
#   'barker',
#   'interweaves',
#   'archival',
#   'footage',
#   'philip',
#   'sheppard',
#   'moody',
#   'music',
#   'contrasting',
#   'lighting',
#   'keep',
#   'film',
#   'sensibility',
#   'nimble',
#   'shifting'],
#  ['initial',
#   'tension',
#   'halfway',
#   'foster',
#   'take',
#   'wrong',
#   'turn',
#   'ensues',
#   'meandering',
#   'thriller',
#   'disguised',
#   'social',
#   'satire',
#   'waste',
#   'star',
#   'cast'],
#  ['instead',
#   'mixing',
#   'comedy',
#   'weighty',
#   'issue',
#   'movie',
#   'simply',
#   'tickle',
#   'nostalgia',
#   'bone',
#   'without',
#   'f',
#   'king',
#   'one',
#   'pie',
#   'process'],
#  ['take', 'demonstrative', 'friendship', 'movie', 'find'],
#  ['control',
#   'go',
#   'past',
#   'clich',
#   'punk',
#   'rock',
#   'god',
#   'gloom',
#   'offer',
#   'snapshot',
#   'alienation',
#   'shockingly',
#   'humane'],
#  ['performance', 'first', 'rate', 'particularly', 'ruffalo', 'phoenix'],
#  ['chaplin',
#   'melancholy',
#   'best',
#   'work',
#   'short',
#   'time',
#   'keaton',
#   'stage',
#   'together',
#   'priceless'],
#  ['winter',
#   'paint',
#   'valiant',
#   'austrian',
#   'economist',
#   'libertarian',
#   'politics',
#   'filtered',
#   'open',
#   'source',
#   'software',
#   'fighting',
#   'evil',
#   'government',
#   'failure',
#   'see',
#   'villain',
#   'side',
#   'undercut',
#   'argument'],
#  ['ricky',
#   'gervais',
#   'carried',
#   'proper',
#   'big',
#   'hollywood',
#   'film',
#   'may',
#   'natural',
#   'done',
#   'without',
#   'hesitation',
#   'cultural',
#   'cringe',
#   'apologetic',
#   'foregrounding',
#   'britishness',
#   'cracked'],
#  ['one',
#   'awkward',
#   'film',
#   'depicts',
#   'complacent',
#   'character',
#   'looking',
#   'complacent',
#   'silva',
#   'never',
#   'quite',
#   'seems',
#   'control',
#   'volatile',
#   'material'],
#  ['feel',
#   'pity',
#   'vince',
#   'vaughn',
#   'jon',
#   'favreau',
#   'co',
#   'wrote',
#   'piece',
#   'co',
#   'star',
#   'hope',
#   'career',
#   'killer',
#   'worth',
#   'paycheck'],
#  ['gap',
#   'narrative',
#   'little',
#   'tarnish',
#   'impact',
#   'stirring',
#   'tale',
#   'offer',
#   'big',
#   'heart',
#   'quick',
#   'foot',
#   'mood',
#   'story',
#   'reinforces',
#   'power',
#   'human',
#   'spirit'],
#  ['done',
#   'evident',
#   'love',
#   'sensitivity',
#   'hard',
#   'imagine',
#   'human',
#   'connecting',
#   'way',
#   'perhaps',
#   'even',
#   'learning',
#   'something',
#   'along',
#   'way'],
#  ['humorless',
#   'even',
#   'borderline',
#   'pretentious',
#   'exercise',
#   'sick',
#   'scaremongering'],
#  ['people',
#   'love',
#   'sci',
#   'fi',
#   'film',
#   'probably',
#   'find',
#   'thing',
#   'like',
#   'looking',
#   'slick',
#   'production',
#   'better',
#   'look',
#   'elsewhere'],
#  ['downey',
#   'imbues',
#   'superhero',
#   'heart',
#   'glow',
#   'radiantly',
#   'power',
#   'reactor',
#   'implant',
#   'chest'],
#  ['beautifully',
#   'rendered',
#   'document',
#   'testament',
#   'human',
#   'perseverance',
#   'strength',
#   'character',
#   'resides',
#   'individual',
#   'faced',
#   'specter',
#   'certain',
#   'death'],
#  ['dreary', 'misogynistic'],
#  ['give',
#   'film',
#   'decent',
#   'score',
#   'would',
#   'insult',
#   'many',
#   'low',
#   'budget',
#   'feature',
#   'scrape',
#   'every',
#   'penny',
#   'find',
#   'together',
#   'produce',
#   'something',
#   'good'],
#  ['end',
#   'film',
#   'misstep',
#   'failure',
#   'sufficiently',
#   'morally',
#   'gray',
#   'thriller',
#   'smudge',
#   'palette',
#   'beyond',
#   'recognition'],
#  ['adaptation',
#   'kevin',
#   'kwan',
#   'glamour',
#   'novel',
#   'glitzy',
#   'spectacle',
#   'ton',
#   'heart'],
#  ['smoke', 'mirror', 'disguising', 'great', 'vapid', 'emptiness'],
#  ['neighbor', 'movie', 'profound', 'spiritual', 'experience'],
#  ['annoying',
#   'lady',
#   'one',
#   'ever',
#   'considers',
#   'possibility',
#   'nothing',
#   'magical',
#   'actually',
#   'occurring',
#   'film',
#   'start',
#   'silly',
#   'get',
#   'sillier'],
#  ...]

# %%
new_element =[]
for element in docs_wordnet_test:
    test = " ".join(element)
    new_element.append(test) 
type(new_element)
new_series_test = pd.Series(new_element)
new_series_test
col = "text"
new_df_test = pd.DataFrame(new_series_test,columns = [col])
new_df_test
# Out:
#                                                    text
# 0            exultant comedy american repression revolt
# 1         moving term invigorating conversation starter
# 2     bullett raja director tigmanshu dhulia commerc...
# 3     infinitely polar bear vivid snapshot one famil...
# 4     disney pixar animation quality especially appe...
# 5                    de bont simply reprises first film
# 6     least cinematic train look pretty run track dr...
# 7     performance make material human accessible mai...
# 8     filmmaker possessed mutation travel back time ...
# 9     helen mirren commanding performance elizabeth ...
# 10    robert zemeckis walk breathtaking hope film ma...
# 11    dark shadow amusing fit spurt sure make ton mo...
# 12    saul dibb foamy adaptation amanda foreman geor...
# 13    anders danielsen lie give compelling deep etch...
# 14    actor support translates screen real communion...
# 15    surprisingly subtle take aging changing role r...
# 16    arguably spin control last act overall make wi...
# 17    movie think tomik pretty sick puppy kieslowski...
# 18    full insanely grand passion bloodthirsty viole...
# 19    movie raw ambition spirit literally reinvents ...
# 20    yes absolutely fun well many many thing go boo...
# 21    another sure fire cult hit mancini take chucky...
# 22    deliberately old fashioned ww adventure shine ...
# 23    extraordinary magical wondrous blessedly origi...
# 24           w fail drama comedy unclear sequence meant
# 25    miss sloane heroine driven craftiness film sub...
# 26    facial jewellery elvis costello music cell pho...
# 27          film effective need equalizer line see find
# 28    lifeless number production excruciating exerci...
# 29    predator gut slash way gory sci fi mediocrity ...
# ...                                                 ...
# 2470  none dahl gift dark humor sparkling writing ev...
# 2471  knight cup film feel something important say m...
# 2472  proof positive emperor comedy clothes fact see...
# 2473  comedic crimer late cycle tarantino retread py...
# 2474                             glorious new territory
# 2475  premise look film admittedly innovative scary ...
# 2476  took still shot one middle action sequence nee...
# 2477  duff make long comparatively dostoyevskian dep...
# 2478  maturely written richly characterized flawless...
# 2479     scare quote around movie title never necessary
# 2480  hero iconic inertia photographed molten sky ju...
# 2481                            different anything came
# 2482               loud garish untimely romantic comedy
# 2483  emotionally rewarding reunion tour established...
# 2484  film delight aspect disappoints others deft jo...
# 2485  would take actual work get absolutely everythi...
# 2486  bad leslie dixon tapped le percent penning und...
# 2487  many reason treasure david lowery new film gho...
# 2488  joss whedon fan want miss shakespeare fan want...
# 2489  watching movie like going quantum physic sympo...
# 2490  make cousin rachel engaging audience never qui...
# 2491  audacious performance veteran actor wonderful ...
# 2492  many moving part spinning many direction movie...
# 2493  fool shame fool twice shame fool thrice sequel...
# 2494  quarantine unavoidable american replica versio...
# 2495  journey function primarily hopeful story peopl...
# 2496  fascinating doc couple son nazi war criminal o...
# 2497  one film running gag despite unfolding apocaly...
# 2498  much movie good work undone silly unconvincing...
# 2499  virtually one zion age except esteemed charact...
#
# [2500 rows x 1 columns]

# %%
X_test_counts = cv.transform(df_test.Review.values)
#X_test_counts_arr = X_test_counts.toarray()
#X_test_counts_arr
X_test_tfidf = tfidf_transformer.transform(X_test_counts)
X_test_arr = X_test_tfidf.toarray()
# #print(X_test_arr.shape)
# #X_test_std= scaler.fit_transform(X_temp)
# y_test = new_df_test["Freshness"].values
# #print(X_test_counts.shape)
# print(X_test_arr.shape)
nb_model.score(X_train_tfidf_arr,y)
# Out:
# 0.802

# %%
nb_model.score(X_test_arr, y_test)
# Out:
# 0.5088

# %%
ans = nb_model.predict_proba(X_test_arr)
ans
# Out:
# array([[0.68559888, 0.31440112],
#        [0.37250548, 0.62749452],
#        [0.6513252 , 0.3486748 ],
#        ...,
#        [0.51082935, 0.48917065],
#        [0.2991303 , 0.7008697 ],
#        [0.35966766, 0.64033234]])

# %%
y_predict = nb_model.predict(X_test_arr)
y_predict
# Out:
# array([0, 1, 0, ..., 0, 1, 1])

# %%
sum(y_predict)
# Out:
# 1175

# %%
from sklearn import metrics

# %%
metrics.confusion_matrix(y_test, y_predict)
# Out:
# array([[692, 595],
#        [633, 580]])

# %%
#false positives
false_positives = new_df_test[y_predict > y_test]
false_positives
# Out:
#                                                    text
# 6     least cinematic train look pretty run track dr...
# 11    dark shadow amusing fit spurt sure make ton mo...
# 25    miss sloane heroine driven craftiness film sub...
# 34    problem try stuff romantic comedy episodic eve...
# 35                                         le fantastic
# 41    contain exactly two memorable scene rest rockn...
# 51    marie curie get look right costume creation ea...
# 69    technically excellent throughout style strong ...
# 74    overly long superficial shallow closet updated...
# 78                   much movie play like civics lesson
# 79    make original urban legend look like alfred hi...
# 83    clumsiness follows clumsiness acting staging d...
# 87    might leigh worst film worst thing ever say fi...
# 90             novelty quickly fade since guessed story
# 91    film let overlong running time prurient attemp...
# 95    beastly quite cover even monstrous gruesome gr...
# 97    motivation earnest handsome well acted unenlig...
# 101   love grown ups may feel seen lot especially ca...
# 105   vhs viral manages improve upon predecessor str...
# 108           lobster like crustacean delivered segment
# 110   parker anti carrie bradshaw messiness coupled ...
# 113   composed subtlety jack hammer narrated fantasy...
# 121                  let one go voicemail watch instead
# 127   service turn find filmmaker hidden narrative r...
# 132       might give restless night fell asleep theater
# 141                   great effect bad acting look like
# 145   carry residue something much harsher something...
# 148   grim shrill deluded incredibly depressing movi...
# 149            play like clumsily opened fringe theatre
# 163                              contrived manipulative
# ...                                                 ...
# 2383  call pointless endeavor except might finally a...
# 2385  suffers abusive close ups repetitive fight seq...
# 2389  new ghostbusters frequently funny although mov...
# 2390  ok ignore transsexual cow whole thing mish mas...
# 2391  muhammad ali may ability float like butterfly ...
# 2392  one get sense dante gift better served big san...
# 2396  transformer delivers promise stunning visuals ...
# 2403  wish funnier smarter wish better production va...
# 2409  relatively concise passion project end stop vi...
# 2411  movie tagline read get fast enough thinking thing
# 2417  feeble beverly hill cop knockoff give audience...
# 2420  young viewer might distracted enough log sledd...
# 2422  film never transcends subject matter informati...
# 2424  take group argentinian cop crack exactly metap...
# 2431  respect core character offer anything new full...
# 2437  darker flail indecisively elegance lewdness en...
# 2442  problem start levinson script overemploys patr...
# 2454            movie shapeless mess land pathetic thud
# 2458         stereotype sexism violence terrible remake
# 2461  sometimes stupid funny mostly plain stupid slo...
# 2465  rendition worst flaw political deck stacking w...
# 2473  comedic crimer late cycle tarantino retread py...
# 2475  premise look film admittedly innovative scary ...
# 2476  took still shot one middle action sequence nee...
# 2479     scare quote around movie title never necessary
# 2480  hero iconic inertia photographed molten sky ju...
# 2485  would take actual work get absolutely everythi...
# 2489  watching movie like going quantum physic sympo...
# 2492  many moving part spinning many direction movie...
# 2494  quarantine unavoidable american replica versio...
#
# [595 rows x 1 columns]

# %%
#false negatives
false_neg = new_df_test[y_predict < y_test]
false_neg
# Out:
#                                                    text
# 0            exultant comedy american repression revolt
# 3     infinitely polar bear vivid snapshot one famil...
# 4     disney pixar animation quality especially appe...
# 9     helen mirren commanding performance elizabeth ...
# 13    anders danielsen lie give compelling deep etch...
# 14    actor support translates screen real communion...
# 18    full insanely grand passion bloodthirsty viole...
# 19    movie raw ambition spirit literally reinvents ...
# 20    yes absolutely fun well many many thing go boo...
# 22    deliberately old fashioned ww adventure shine ...
# 23    extraordinary magical wondrous blessedly origi...
# 27          film effective need equalizer line see find
# 32    mendes working script husband wife hipster dav...
# 36    film belongs noble heritage beery dvd night ta...
# 39    well crafted bravely revealing little film cou...
# 43    film tale youthful innocence mature disillusio...
# 47    irresistible combination rousing good story se...
# 48         stunning baffling pretentious brilliant life
# 50    girl played fire nearly admirable dragon tatto...
# 56    expect thriller seat edge sense thrilled repul...
# 59    follows unremittingly pursues two greatest the...
# 61    movie brimming beautiful people beautiful scen...
# 66    film adult enjoy without feeling obligation ta...
# 71    dan real life pretty warm genuine comedy succe...
# 73    one finest film artist ever made fashioned fil...
# 76    goodnight mommy brilliantly unnerving outset f...
# 81    step another vehicle showcasing latest creativ...
# 82    absolutely ingenious know car car movie richer...
# 86    thor ragnarok fun thor movie long shot still m...
# 88    eminem manages take think know eminem inject c...
# ...                                                 ...
# 2356  may biggest flat screen dlp monitor city red c...
# 2357  south korean police thriller find helmer scrib...
# 2363  movie struggle keep momentum stall actual heis...
# 2373            really immersed believable world future
# 2375  best skull island delivers colossal big screen...
# 2378  spider man homecoming improbable successfully ...
# 2393                      something divinely unsettling
# 2395  providing fascinating insight one history bloo...
# 2399                        step vh behind music series
# 2401  gone girl suspenseful entertaining hour runnin...
# 2402  movie le biting originality truman show prof d...
# 2404  committee engineered product designed boost fi...
# 2408  something heroic persistence self belief kudlo...
# 2410  urge enjoy big screen importantly part communa...
# 2418  good intense war movie fall short great one ad...
# 2419  go get ticket join hullabaloo confident time g...
# 2426  almost palpable earnestness reverence communit...
# 2428                       fan lavish period drama love
# 2429  looking diverting sci fi actioner handily mix ...
# 2436  larson delivers promise attention getting perf...
# 2440  one best thing willow creek represents someone...
# 2441  film lively invention pay however reach epic s...
# 2447  hidden figure compelling full heart engaging t...
# 2460  sequel surprise hit bigger colorful wacko firs...
# 2468  disgusting rowdy comedy amazing amount heart m...
# 2469  far polished sheen recent cgi feature animatio...
# 2481                            different anything came
# 2487  many reason treasure david lowery new film gho...
# 2491  audacious performance veteran actor wonderful ...
# 2496  fascinating doc couple son nazi war criminal o...
#
# [633 rows x 1 columns]

# %%
X_train_counts_fp = cv.transform(false_positives["text"].values)
word_freq_fp = dict(zip(cv.get_feature_names(), np.asarray(X_train_counts_fp.sum(axis=0)).ravel()))
word_counter_fp = Counter(word_freq_fp)
word_counter_df_fp = pd.DataFrame(word_counter_fp.most_common(20), columns = ['word', 'freq'])

X_train_counts_fn = cv.transform(false_neg["text"].values)
word_freq_fn = dict(zip(count_vect.get_feature_names(), np.asarray(X_train_counts_fn.sum(axis=0)).ravel()))
word_counter_fn = Counter(word_freq_fn)
word_counter_df_fn = pd.DataFrame(word_counter_fn.most_common(20), columns = ['word', 'freq'])

# %%
fig, ax = plt.subplots(figsize=(12, 10))
#plt.subplot(1,2,1)
sns.barplot(x="word", y="freq", data=word_counter_df_fp, palette="PuBuGn_d", ax=ax)
#plt.subplot(1,2,2)
#ax[0,1]= sns.barplot(x="word", y="freq", data=word_counter_df_neg, palette="PuBuGn_d", ax=ax)
plt.xlabel("Word", fontsize=16, fontweight ="bold")
plt.ylabel("Frequency of Word",fontsize = 16,fontweight="bold")
plt.xticks(rotation=45)
plt.title("Most Common Words in False Positive Reviews",fontsize=20)
plt.savefig("images/most_common_words_fp")
plt.show();

# %%
fig, ax = plt.subplots(figsize=(12, 10))
#plt.subplot(1,2,1)
sns.barplot(x="word", y="freq", data=word_counter_df_fn, palette="PuBuGn_d", ax=ax)
#plt.subplot(1,2,2)
#ax[0,1]= sns.barplot(x="word", y="freq", data=word_counter_df_neg, palette="PuBuGn_d", ax=ax)
plt.xticks(rotation=45)
plt.xlabel("Word",fontsize =16, fontweight="bold")
plt.ylabel("Frequency",fontsize =16, fontweight="bold")
plt.title("Most Common Words in False Negative Reviews",fontsize=20)
plt.savefig("images/most_common_words_fn")
plt.show();
